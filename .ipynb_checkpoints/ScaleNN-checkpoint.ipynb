# %% [markdown]
# # 0. Import Packages

# %%
from classy import Class
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
import mcfit
from astropy.table import Table
from astropy.io import ascii
import os

import torch
from torch import nn, optim
from torch.utils.data import TensorDataset, DataLoader

from numpy.polynomial import Polynomial

# %% [markdown]
# # 1. Testing Linear CF with Planck cosmology using ``Class``
#
# ### Set Parameters

# %%
# min and max power
k_min = 1e-5
k_max = 1e3

# H0 and h parameters
H0 = 67.11
h = H0/100

# set cosmological parameters
params = {'output' : 'mPk',
         'omega_b' : 0.049*h**2,
         'omega_cdm' : (0.3175 - 0.049)*h**2,
         'H0' : H0,
         'n_s' : 0.9624,
         'sigma8' : 0.834,
         'N_eff' : 3.046,
         'P_k_max_1/Mpc' : k_max,
         'z_max_pk' : 100.}

# %% [markdown]
# ### Compute cosmology with ``Class``

# %%
cosmo = Class()
cosmo.set(params)
cosmo.compute()

# %% [markdown]
# ### Set redshift for power spectrum/correlation function

# %%
z = 0.0

# %% [markdown]
# ### Get power spectrum at redshift z

# %%
klin = np.logspace(np.log10(k_min), np.log10(k_max), num=10000) # units 1/Mpc

Pklin = np.array([cosmo.pk_lin(ki, z) for ki in klin]) # power spectrum at scales klin

klin /= h # convert 1/Mpc to h/Mpc^-1
Pklin *= h**3 # convert Mpc^3 to (Mpc/h)^3

# %% [markdown]
# ### Get CF DD term (redshift growth factor)

# %%
cosmo.scale_independent_growth_factor(z)
# Out:
# 1.0

# %% [markdown]
# ### Plot power spectrum

# %%
fig = plt.figure(figsize=[5, 3], dpi=500)
plt.plot(klin, Pklin, lw = 0.5)

plt.ylabel('$P(k)$  $[(h^{-1}$ Mpc$)^3]$', fontsize=6)

plt.xlabel('$k$  $[h$ Mpc$^{-1}]$', fontsize=6)

plt.xlim(1e-4, 10)
plt.ylim(1, 4*1e4)
plt.xscale('log')
plt.yscale('log')
plt.tick_params(axis='both', which='major', labelsize=6)
plt.title('Power Spectrum', fontsize=8)
# Out:
# Text(0.5, 1.0, 'Power Spectrum')

# %% [markdown]
# ### Get correlation function from power spectrum

# %%
CF = mcfit.P2xi(klin, l=0, lowring=True) # correlation function
r_lin, xi_lin = CF(Pklin, extrap=True) # r, xi of linear correlation function

# %% [markdown]
# ### Spline fit to get critical points, linear point, and point of inflection

# %% [markdown]
# Can only calculate roots on degree three spline fit, so we need a degree 4 and degree 5 initial spline fits to get roots on the first and second derivatives

# %% [markdown]
# #### Critical points and linear point

# %%
spl = UnivariateSpline(r_lin, xi_lin, k=4, s=0) # degree 4 spline fit

dx = spl.derivative() # first derivative
cp = dx.roots() # critical points (roots of first derivative)

dip = cp[0] # first critical point is dip
peak = cp[1] # second critical point is peak
lp = (dip+peak)/2.0 # linear point is halfway between dip and peak

# %% [markdown]
# #### Point of inflection

# %%
mask = (r_lin < peak) & (r_lin > dip) # only want to look for inflection point between dip and peak, since there may be many
rMasked = r_lin[mask]
xiMasked = xi_lin[mask]

spl2 = UnivariateSpline(rMasked, xiMasked, k=5, s=0) # degree 5 spline fit to CF between dip and peak
dx2 = spl2.derivative(2) # second derivative
ip = dx2.roots()[0] # inflection point is root of second derivative

# %% [markdown]
# ### Plot correlation function with all scales

# %%
fig = plt.figure(figsize=[5, 2.5], dpi=500)

deep_r = np.linspace(50, 125, 100000) # add spatial resolution

## Add vertical/horizontal width in plot ##
r_min, r_max = dip - 25, peak + 25
xi_max = spl(peak)*1.2
if min(spl(deep_r)) <= 0:
    xi_min = min(spl(deep_r))*1.4
else:
    xi_min = min(spl(deep_r))*0.8
    
## Plotting ##
plt.plot(r_lin, xi_lin, lw=1, label='CF') # plot CF

plt.plot(deep_r, dx(deep_r), lw=0.5, ls = '--', label = '$d\\xi/dr$') # plot first derivative
plt.plot(deep_r, dx2(deep_r), lw=0.5, ls = '--', label='$d^2\\xi/dr^2$') # plot second derivative

# plot scales
plt.vlines([dip, peak], ymin=xi_min, ymax=xi_max, color='r', lw=0.5, ls='-.', label='Dip/peak')
plt.vlines(lp, ymin=xi_min, ymax=xi_max, color='b', lw=0.5, ls='-.', label='LP')
plt.vlines(ip, ymin=xi_min, ymax=xi_max, color='g', lw=0.5, ls='-.', label='IP')
plt.scatter([dip, peak, lp, ip], [spl(dip), spl(peak), spl(lp), spl(ip)], c=['r', 'r', 'b', 'g'], s=2, zorder=1000)
plt.scatter([dip, peak, lp, ip], np.zeros(4), c=['r', 'r', 'b', 'g'], s=1, zorder=1000)

plt.hlines(0, xmin=r_min, xmax=r_max, lw=0.2, ls='--') # plot horizontal axis

# figure parameters
plt.xlim(r_min, r_max)
plt.ylim(xi_min, xi_max)

plt.xlabel('r  $[h^{-1}$ Mpc]', fontsize=6)
plt.ylabel('$\\xi(r)$', fontsize=6)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.title('Correlation Function', fontsize=8)
plt.legend(fontsize=4)

# %% [markdown]
# #### Zoom in on derivatives

# %%
fig = plt.figure(figsize=[5, 2.5], dpi=500)

## Add vertical/horizontal width in plot ##
r_min, r_max = dip - 10, peak + 10
deep_r = np.linspace(r_min, r_max, 100000) # add spatial resolution
y_max = np.max(dx(deep_r))*1.2
if np.min(dx(deep_r)) <= 0:
    y_min = np.min(dx(deep_r))*1.2
else:
    y_min = np.min(dx(deep_r))*0.8
    
## Plotting ##
plt.plot(deep_r, dx(deep_r), lw=0.5, ls = '--', label = '$d\\xi/dr$') # plot first derivative
plt.plot(deep_r, dx2(deep_r), lw=0.5, ls = '--', label='$d^2\\xi/dr^2$') # plot second derivative

# plot scales
plt.vlines([dip, peak], ymin=xi_min, ymax=xi_max, color='r', lw=0.5, ls='-.', label='Dip/peak')
plt.vlines(ip, ymin=xi_min, ymax=xi_max, color='g', lw=0.5, ls='-.', label='IP')
plt.scatter([dip, peak, ip], np.zeros(3), c=['r', 'r', 'g'], s=1, zorder=1000)

plt.hlines(0, xmin=r_min, xmax=r_max, lw=0.2, ls='--') # plot horizontal axis

# figure parameters
plt.xlim(r_min, r_max)
plt.ylim(y_min, y_max)

plt.xlabel('r  $[h^{-1}$ Mpc]', fontsize=6)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.title('Correlation Function Derivatives', fontsize=8)
plt.legend(fontsize=4)

# %% [markdown]
# # 2. Comparison to Quijote Simulations

# %% [markdown]
# #### ```computeLinearCF.py``` contains functions to do all the above with linear evolution
#
# Can run this file with ````python computeLinearCF.py```` to calculate all the linear CFs based on the Quijote latin hypercube parameter file at ```latinHypercubeParameters.txt```, or can calculate each cosmology individually with these functions

# %%
from computeLinearCF import cosmology, corr, scales

# %% [markdown]
# #### Define a function to take a quijote CF text file and return an astropy table
#
# Searches for files with name ````latin_hypercube/(simulation number)/CF_m_1024_z=(redshift).txt````

# %%
def txt_to_table(sim_num, redshift): # converts text file of simulation to an astropy table
    simulation = f'latin_hypercube/{sim_num}/CF_m_1024_z={redshift}.txt' # input text file
    sim_list = []
    for line in open(simulation, 'r'): # get each line
        item = line.rstrip() # strip off newline and any other trailing whitespace
        sim_list.append(item)
        
    r_list, xi_list = [], []
    for item in sim_list: # get radius and correlation from each line
        r, xi = item.split() # each line has both radius and correlation, so split
        r_list.append(float(r))
        xi_list.append(float(xi))
        
    sim_table = Table([r_list, xi_list], names=('r', 'xi')) # astropy table
    return sim_table

# %% [markdown]
# ### Testing code on Quijote simulations
# #### Pick a simulation number

# %%
number = 5

# %% [markdown]
# #### Read in linear CF

# %%
linCFfile = ascii.read(f'linearCF/linearCF{number}.dat')  
linCF = Table(linCFfile)

# %% [markdown]
# #### Read in Quijote CFs

# %%
nonLin = txt_to_table(number, 0) # z = 0
nonLin2 = txt_to_table(number, 3) # z = 3

# %% [markdown]
# #### Get linear scales from linear CF

# %%
dip, peak, lp, ip = scales(linCF)

# %%
fig = plt.figure(figsize=[5, 2.5], dpi=500)

spl = UnivariateSpline(linCF['r'], linCF['xi'], k=4, s=0) # degree 4 spline fit

## Add vertical/horizontal width in plot ##
r_min, r_max = dip - 50, peak + 50
xi_max = spl(peak)*1.2
if np.min(linCF['xi']) <= 0:
    xi_min = np.min(linCF['xi'])*1.4
else:
    xi_min = np.min(linCF['xi'])*0.8
    


plt.plot(linCF['r'], linCF['xi'], c='r', label='Linear z=0 CF')

plt.vlines([dip, peak], ymin=xi_min, ymax=xi_max, color='r', lw=0.5, ls='-.', label='Dip/peak')
plt.vlines(lp, ymin=xi_min, ymax=xi_max, color='b', lw=0.5, ls='-.', label='LP')
plt.vlines(ip, ymin=xi_min, ymax=xi_max, color='g', lw=0.5, ls='-.', label='IP')
plt.scatter([dip, peak, lp, ip], [spl(dip), spl(peak), spl(lp), spl(ip)], c=['r', 'r', 'b', 'g'], s=2, zorder=1000)

plt.plot(nonLin['r'], nonLin['xi'], label='Quijote z=0 CF')
plt.plot(nonLin2['r'], nonLin2['xi'], label='Quijote z=3 CF')






# figure parameters
plt.xlim(r_min, r_max)
plt.ylim(xi_min, xi_max)


plt.xlabel('r  $[h^{-1}$ Mpc]', fontsize=6)
plt.ylabel('$\\xi(r)$', fontsize=6)
plt.tick_params(axis='both', which='major', labelsize=6)
plt.title('Correlation Function', fontsize=8)
p = plt.legend(fontsize=4)

# %% [markdown]
# #### Test which CFs don't have dip/peak for $\xi r^2$

# %%
dipList = []
peakList = []
lpList = []
ipList = []
startIndex = 0
endIndex = 250
for i in range(startIndex, endIndex):
    linCFfile = ascii.read(f'linearCF/linearCF{i}.dat')  
    linCF = Table(linCFfile)
    maskCF = (linCF['r'] < 200) & (linCF['r'] > 40)
    linCF = linCF[maskCF]
    linCF['xi'] *= linCF['r']**2
    
    try:
        dip, peak, lp, ip = scales(linCF)
        dipList.append(dip)
        peakList.append(peak)
        lpList.append(lp)
        ipList.append(ip)
    except:
        print(i)
    
#scaleTable = Table([range(startIndex, endIndex), dipList, peakList, lpList, ipList], names=('CF', 'dip', 'peak', 'lp', 'ip')) # astropy table
# Out:
# 12
# 18
# 22
# 42
# 71
# 75
# 91
# 94
# 95
# 96
# 99
# 106
# 118
# 154
# 155
# 164
# 191
# 194
# 199
# 203
# 207
# 212
# 237
# 240
# 246

# %% [markdown]
# A lot of cosmologies in just the first 250 don't have dips and/or peaks for $\xi r^2$

# %% [markdown]
# #### And which don't have for $\xi$

# %%
dipListx = []
peakListx = []
lpListx = []
ipListx = []

# %%
startIndex = 0
endIndex = 2000
for i in range(startIndex, endIndex):
    linCFfile = ascii.read(f'linearCF/linearCF{i}.dat')  
    linCF = Table(linCFfile)
    maskCF = (linCF['r'] < 200) & (linCF['r'] > 40)
    linCF = linCF[maskCF]
    
    try:
        dip, peak, lp, ip = scales(linCF)
        dipListx.append(dip)
        peakListx.append(peak)
        lpListx.append(lp)
        ipListx.append(ip)
    except:
        print(i)
# Out:
# 244
# 763

# %% [markdown]
# Meanwhile only 2 are missing a dip and/or peak in $\xi$, so let's use these instead

# %%
numListx = np.arange(0, 2000)
numListx = np.delete(numListx, [244, 763])

# %%
scaleTable = Table([numListx, dipListx, peakListx, lpListx, ipListx], names=('CF', 'dip', 'peak', 'lp', 'ip')) # astropy table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 scaleTable = Table([numListx, dipListx, peakListx, lpListx, ipListx], names=('CF', 'dip', 'peak', 'lp', 'ip'))
#
# NameError: name 'numListx' is not defined

# %% [markdown]
# #### Save/read in scale table (linear point, inflection point, dip and peak for all cosmologies)

# %%
# Run this cell to save scale table
scaleTable.write(f'scaleTable.dat', format='ascii', overwrite=False)

# %%
# Run this cell to read in scale table
scaleTableFile = ascii.read(f'scaleTable.dat')  
scaleTable = Table(scaleTableFile)

# %%
fig = plt.figure(figsize=[9,4], dpi=200)
plt.hist(scaleTable['lp'], bins=20)

plt.xlabel('Linear Point (h$^{-1}$ Mpc)')
p = plt.ylabel('Counts')

# %% [markdown]
# # 3. Check that fiducial cosmology at z=127 agrees with linear result

# %%
def txt_to_table_fiducial(sim_num): # converts text file of simulation to an astropy table
    simulation = f'fiducialCF/{sim_num}/CF_m_z=127.txt' # input text file
    sim_list = []
    for line in open(simulation, 'r'): # get each line
        item = line.rstrip() # strip off newline and any other trailing whitespace
        sim_list.append(item)
        
    r_list, xi_list = [], []
    for item in sim_list: # get radius and correlation from each line
        r, xi = item.split() # each line has both radius and correlation, so split
        r_list.append(float(r))
        xi_list.append(float(xi))
        
    sim_table = Table([r_list, xi_list], names=('r', 'xi')) # astropy table
    return sim_table

# %%
# set cosmological parameters
omega_b = 0.049
omega_m = 0.3175
n_s = 0.9624
sigma_8 = 0.834
h = 0.6711
            
cosmo = cosmology(omega_m, omega_b, h, n_s, sigma_8, zmax=130)

# %%
k_min = 1e-5
k_max = 1e3
cf = corr(cosmo, k_min, k_max, z=127)

# %%
r, xi2 = cf['r'], cf['xi']
fdip, fpeak, flp, fip = scales(cf)

# %% [markdown]
# #### Average over 10 different fiducial CFs

# %%
fiducialNums = [0, 1, 10, 100, 1000, 10000, 10001, 10002, 10003, 10004]

# %%
xiArray = np.zeros([len(fiducialNums), len(txt_to_table_fiducial(0))])

# %%
for i in range(len(fiducialNums)):
    xi = np.array(txt_to_table_fiducial(fiducialNums[i])['xi'])
    xiArray[i] = xi

# %%
fig = plt.figure(figsize=[6, 3], dpi=200)

plt.plot(txt_to_table_fiducial(fiducialNums[i])['r'], np.mean(xiArray, axis=0), label='z=127 Quijote CF')
plt.plot(r, xi2, c='r', ls='--', label='z=127 CLASS CF')

plt.vlines([fdip, fpeak, flp], ymin=-0.1, ymax=0.1, color='b', lw=0.5)
plt.vlines(fip, ymin=-0.1, ymax=0.1, color='g', lw=0.5)
         
plt.ylim(-5e-7,1e-6)
plt.xlim(40,150)
plt.legend()

# %% [markdown]
# We see close agreement between the two

# %% [markdown]
# # 4. Train Linear Point Neural Network

# %% [markdown]
# #### Function for binning Quijote correlation functions

# %%
def binCorr(corrTable, binSize):
    rad = corrTable['r']
    xi = corrTable['xi']
    
    rSpacing = np.diff(rad)
    
    npoints = binSize + 1 # binSize is the width of each bin, and there is one more point than bins
    
    radBins = rad[0:-1:binSize]
    originalBinWidths = 0.5*np.diff(rad)[0:-1:binSize]
    if len(radBins) > len(originalBinWidths):
        radBinBounds = radBins[:-1] + 0.5*np.diff(rad)[0:-1:binSize] # new bin boundaries
    else:
        radBinBounds = radBins + 0.5*np.diff(rad)[0:-1:binSize] # new bin boundaries

    newRad = radBinBounds[:-1] + np.diff(radBinBounds)/2. # new bin centers
    binWidths = np.diff(radBinBounds)/2.

    newCorrTable = np.zeros(len(newRad))
    
    for i in range(len(newRad)):
        newCorr = 0
        for j in range(binSize):
            point = binSize*i + j + 1
            spacePoint = binSize*i + j
            pointCorr = ((rad[point] + (rSpacing[spacePoint+1]/2))**3 - (rad[point] - (rSpacing[spacePoint]/2))**3)*xi[point]
            newCorr += pointCorr
        

        newCorr /= ((newRad[i] + binWidths[i])**3 - (newRad[i] - binWidths[i])**3)
        
        newCorrTable[i] = newCorr
    

        
    
    binnedTable = Table([newRad, newCorrTable], names=('r', 'xi')) # astropy table

    return binnedTable

# %% [markdown]
# #### Function to return array of input correlation functions and output linear points

# %%
def dataPull(inputStart, inputEnd, binning=True, nBins=3):
    inputs_xiTable = []
    inputs_rTable = []
    lpsTable = []
    
    # get data
    for x in scaleTable['CF']: # all simulations with scales
        # get r, xi
        inputTable = txt_to_table(x, 0)
        if binning:
            inputTable = binCorr(inputTable, nBins)
        
        inputTable = inputTable[(inputTable['r'] <= inputEnd) & (inputTable['r'] >= inputStart)]
        inputs_xiTable.append(inputTable['xi'])                        
        inputs_rTable.append(inputTable['r'])
        
        # get linear point
        lp = scaleTable[scaleTable['CF'] == x]['lp'][0]        
        lpsTable.append(lp)
    
    inputs_xi, inputs_r, lps = np.array(inputs_xiTable), np.array(inputs_rTable), np.array(lpsTable)
    return inputs_r, inputs_xi, lps

# %% [markdown]
# #### Fucntion to return mean and variance of input and outputs

# %%
def meanVar(inputs_xi, lps):
    mean_inputs = np.mean(inputs_xi, 0)
    mean_lps = np.mean(lps)

    var_inputs = np.sqrt(np.var(inputs_xi, 0))
    var_lps = np.sqrt(np.var(lps))
    
    return mean_inputs, mean_lps, var_inputs, var_lps

# %% [markdown]
# #### Function to return ``PyTorch`` dataloaders

# %%
def setDataloaders(inputs_xi, lps, trainTestSplit=1000):
    # which simulations to train on (rest are for testing)
    train_sample_max = trainTestSplit

    # split into training and testing first
    train_inputs = np.copy(inputs_xi[:train_sample_max])
    train_lps = np.copy(lps[:train_sample_max])
    test_inputs = np.copy(inputs_xi[train_sample_max:])
    test_lps = np.copy(lps[train_sample_max:])
    
    
    # divide all correlation functions by mean across training simulations
    # i.e. for each r, the correlations are divided by the average correlation for that r
    mean_xi, mean_lps, var_xi, var_lps = meanVar(train_inputs, train_lps)

    train_inputs -= mean_xi
    test_inputs -= mean_xi

    train_lps -= mean_lps
    test_lps -= mean_lps

    train_inputs /= var_xi
    test_inputs /= var_xi

    train_lps /= var_lps
    test_lps /= var_lps
    
    

    tensor_train_x = torch.Tensor(train_inputs) # transform to torch tensor
    tensor_train_y = torch.Tensor(train_lps)

    tensor_test_x = torch.Tensor(test_inputs) # transform to torch tensor
    tensor_test_y = torch.Tensor(test_lps)


    train_dataset = TensorDataset(tensor_train_x,tensor_train_y) # create datset
    train_dataloader = DataLoader(train_dataset, shuffle=True) # create dataloader

    test_dataset = TensorDataset(tensor_test_x, tensor_test_y) # create datset
    test_dataloader = DataLoader(test_dataset, shuffle=True) # create dataloader
    
    return train_dataloader, test_dataloader

# %% [markdown]
# #### Function to train neural network

# %%
def trainBAOReconNN(model, train_dataloader, test_dataloader, lr=1e-5, epochs=1000):
    
    # mean-squared error loss
    criterion = nn.MSELoss()
    
    # create an optimizer object
    # Adam optimizer with learning rate + decay
    optimizer = optim.Adam(model.parameters(), lr=lr)
    decayRate = 0.999
    lr_scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer=optimizer, gamma=decayRate)

    #### Training ####
    train_losses = []
    test_losses = []

    for epoch in range(epochs):
        train_loss_tot, test_loss_tot = 0, 0

        #################
        # Training Loop #
        #################
        model.train(True)
        
        # train on random small batches #
        
        r = np.random.randint(1, 10)
        i = 1
        
        train_loss = 0
        optimizer.zero_grad()

        for batch_features, batch_labels in train_dataloader:                
            # compute reconstructions
            model_outputs = model(batch_features)

            # compute training reconstruction loss
            train_loss += criterion(model_outputs, batch_labels)
            
            if np.floor(i/r) == i/r:
                # compute accumulated gradients
                train_loss.backward()

                # perform parameter update based on current gradients
                optimizer.step()
                
                # reset train loss
                train_loss = 0
                
                # reset the gradients back to zero
                optimizer.zero_grad()

            
            i += 1



        
        ################
        # Testing Loop #
        ################
        model.train(False)
        for batch_features, batch_labels in test_dataloader:
            # compute reconstructions
            model_outputs = model(batch_features)

            # compute training reconstruction loss
            test_loss = criterion(model_outputs, batch_labels)

            # add the mini-batch training loss to epoch loss
            test_loss_tot += test_loss.item()
            
        for batch_features, batch_labels in train_dataloader:
            # compute reconstructions
            model_outputs = model(batch_features)

            # compute training reconstruction loss
            train_loss = criterion(model_outputs, batch_labels)

            # add the mini-batch training loss to epoch loss
            train_loss_tot += train_loss.item()

        # compute the epoch training loss
        train_loss_tot = train_loss_tot# / len(train_dataloader)
        test_loss_tot = test_loss_tot# / len(test_dataloader)

        # record losses
        train_losses.append(train_loss_tot)
        test_losses.append(test_loss_tot)

        # learning rate decay step
        lr_scheduler.step()

        # display the epoch losses
        print("epoch : {}/{}, train loss = {:.8f}, test loss = {:.8f}".format(epoch + 1, epochs, train_loss_tot, test_loss_tot))
        
    return model, train_losses, test_losses

# %% [markdown]
# #### Our neural network is effectively an encoder, since we are inputting a sequence and outputting a single number, the linear point

# %%
class encoder(nn.Module):
    def __init__(self, **kwargs):
        super().__init__()

        self.encoder = torch.nn.Sequential(
            torch.nn.Linear(in_features=kwargs["input_shape"], out_features=kwargs['features']),
            torch.nn.ReLU(),
            torch.nn.Linear(kwargs["features"], 16),
            torch.nn.ReLU(),
            torch.nn.Linear(16, 8),
            torch.nn.ReLU(),
            torch.nn.Linear(8, 4),
            torch.nn.ReLU(),
            torch.nn.Linear(4, 1))


    def forward(self, features):
        encoded = self.encoder(features)
        return encoded[0]

# %% [markdown]
# #### Set up data and model for training

# %%
inputStart, inputEnd = 40, 160
trainTestSplit = 999
inputs_r, inputs_xi, lps = dataPull(inputStart, inputEnd)

# %%
train_dataloader, test_dataloader = setDataloaders(inputs_xi, lps, trainTestSplit)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
input_shape = len(inputs_xi[0])
nFeatures = 32

# %%
model = encoder(input_shape=input_shape, features=nFeatures).to(device)

# %% [markdown]
# #### Train

# %%
model, train_loss, test_loss = trainBAOReconNN(model, train_dataloader, test_dataloader, lr=2e-5, epochs=5000)
# Out:
# epoch : 1/5000, train loss = 27.46518192, test loss = 55.69513276
# epoch : 2/5000, train loss = 27.40366139, test loss = 56.22519968
# epoch : 3/5000, train loss = 27.42133351, test loss = 56.26752628
# epoch : 4/5000, train loss = 27.61555806, test loss = 55.64927137
# epoch : 5/5000, train loss = 27.48403590, test loss = 56.59771813
# epoch : 6/5000, train loss = 27.43652083, test loss = 55.94187366
# epoch : 7/5000, train loss = 27.40968304, test loss = 55.78974296
# epoch : 8/5000, train loss = 27.52827114, test loss = 56.59085530
# epoch : 9/5000, train loss = 27.74773952, test loss = 55.46525718
# epoch : 10/5000, train loss = 28.89054911, test loss = 58.84766015
# epoch : 11/5000, train loss = 28.04220447, test loss = 54.93003589
# epoch : 12/5000, train loss = 27.58651841, test loss = 56.87538129
# epoch : 13/5000, train loss = 27.41849393, test loss = 55.90099421
# epoch : 14/5000, train loss = 27.48345846, test loss = 55.71590887
# epoch : 15/5000, train loss = 27.64075932, test loss = 57.09679841
# epoch : 16/5000, train loss = 27.44422049, test loss = 56.03908551
# epoch : 17/5000, train loss = 27.79673686, test loss = 55.66250551
# epoch : 18/5000, train loss = 27.78219860, test loss = 55.48097709
# epoch : 19/5000, train loss = 27.39133690, test loss = 55.87380557
# epoch : 20/5000, train loss = 27.37542408, test loss = 56.19188289
# epoch : 21/5000, train loss = 27.38398177, test loss = 56.11899894
# epoch : 22/5000, train loss = 27.40337219, test loss = 55.59651791
# epoch : 23/5000, train loss = 27.84776892, test loss = 57.27558966
# epoch : 24/5000, train loss = 27.40408306, test loss = 55.71244419
# epoch : 25/5000, train loss = 27.39239911, test loss = 56.06708210
# epoch : 26/5000, train loss = 27.56967304, test loss = 56.88182623
# epoch : 27/5000, train loss = 27.49085989, test loss = 56.72260853
# epoch : 28/5000, train loss = 27.43233777, test loss = 56.34129446
# epoch : 29/5000, train loss = 27.45330147, test loss = 56.58921155
# epoch : 30/5000, train loss = 27.33327183, test loss = 56.05458549
# epoch : 31/5000, train loss = 27.81757955, test loss = 55.55168899
# epoch : 32/5000, train loss = 27.70343523, test loss = 56.75885092
# epoch : 33/5000, train loss = 27.76143209, test loss = 55.50307881
# epoch : 34/5000, train loss = 27.42814523, test loss = 56.06322051
# epoch : 35/5000, train loss = 27.31475408, test loss = 56.08236714
# epoch : 36/5000, train loss = 27.41787128, test loss = 55.75340489
# epoch : 37/5000, train loss = 27.42062691, test loss = 56.25756294
# epoch : 38/5000, train loss = 27.43199386, test loss = 55.76904145
# epoch : 39/5000, train loss = 27.31568038, test loss = 55.94623379
# epoch : 40/5000, train loss = 27.29342799, test loss = 56.21769291
# epoch : 41/5000, train loss = 27.54138781, test loss = 56.70167895
# epoch : 42/5000, train loss = 27.29540746, test loss = 55.91104787
# epoch : 43/5000, train loss = 27.32547108, test loss = 56.33105290
# epoch : 44/5000, train loss = 27.43108019, test loss = 56.81811524
# epoch : 45/5000, train loss = 27.61382908, test loss = 55.62390160
# epoch : 46/5000, train loss = 27.64088447, test loss = 55.79618538
# epoch : 47/5000, train loss = 27.61720754, test loss = 56.95588791
# epoch : 48/5000, train loss = 27.52957130, test loss = 56.61464264
# epoch : 49/5000, train loss = 27.30806033, test loss = 55.86670817
# epoch : 50/5000, train loss = 27.28054526, test loss = 55.94930237
# epoch : 51/5000, train loss = 27.28380656, test loss = 55.93408605
# epoch : 52/5000, train loss = 27.71494488, test loss = 55.61065176
# epoch : 53/5000, train loss = 27.25732429, test loss = 56.11511298
# epoch : 54/5000, train loss = 27.26933911, test loss = 56.20111888
# epoch : 55/5000, train loss = 27.32635638, test loss = 56.55656876
# epoch : 56/5000, train loss = 27.48012142, test loss = 55.93268071
# epoch : 57/5000, train loss = 27.34588876, test loss = 56.16955142
# epoch : 58/5000, train loss = 27.28695193, test loss = 56.37112352
# epoch : 59/5000, train loss = 27.77463988, test loss = 57.11330195
# epoch : 60/5000, train loss = 27.61923753, test loss = 57.05224851
# epoch : 61/5000, train loss = 27.32148292, test loss = 55.90019340
# epoch : 62/5000, train loss = 27.26659820, test loss = 56.26964862
# epoch : 63/5000, train loss = 27.30300918, test loss = 56.46488793
# epoch : 64/5000, train loss = 27.53632700, test loss = 55.44947733
# epoch : 65/5000, train loss = 27.27094993, test loss = 56.07552414
# epoch : 66/5000, train loss = 27.39934650, test loss = 55.54837938
# epoch : 67/5000, train loss = 27.41648665, test loss = 56.93178687
# epoch : 68/5000, train loss = 27.34687769, test loss = 55.78072937
# epoch : 69/5000, train loss = 27.27198346, test loss = 56.01074990
# epoch : 70/5000, train loss = 27.33131277, test loss = 55.78200616
# epoch : 71/5000, train loss = 27.47389943, test loss = 56.91193443
# epoch : 72/5000, train loss = 27.27713965, test loss = 56.30888446
# epoch : 73/5000, train loss = 27.37843739, test loss = 56.80951748
# epoch : 74/5000, train loss = 27.28885025, test loss = 55.78066431
# epoch : 75/5000, train loss = 27.26374061, test loss = 55.64302919
# epoch : 76/5000, train loss = 27.40860074, test loss = 56.68047305
# epoch : 77/5000, train loss = 27.21766862, test loss = 55.84905679
# epoch : 78/5000, train loss = 27.21368124, test loss = 55.85512068
# epoch : 79/5000, train loss = 27.36708061, test loss = 55.63463566
# epoch : 80/5000, train loss = 27.20100341, test loss = 55.79136202
# epoch : 81/5000, train loss = 27.40821047, test loss = 55.54244456
# epoch : 82/5000, train loss = 27.54468534, test loss = 56.79625978
# epoch : 83/5000, train loss = 27.29423565, test loss = 56.59418163
# epoch : 84/5000, train loss = 27.26326253, test loss = 55.56938146
# epoch : 85/5000, train loss = 27.25796340, test loss = 56.21043156
# epoch : 86/5000, train loss = 27.20357355, test loss = 55.90631709
# epoch : 87/5000, train loss = 27.16616351, test loss = 55.87777707
# epoch : 88/5000, train loss = 27.15493699, test loss = 56.01903334
# epoch : 89/5000, train loss = 27.51778007, test loss = 57.06966543
# epoch : 90/5000, train loss = 27.58153281, test loss = 55.43269472
# epoch : 91/5000, train loss = 27.40088895, test loss = 56.54529407
# epoch : 92/5000, train loss = 27.87427532, test loss = 55.59631405
# epoch : 93/5000, train loss = 27.60344129, test loss = 55.38185333
# epoch : 94/5000, train loss = 27.16603862, test loss = 55.83282922
# epoch : 95/5000, train loss = 27.33009605, test loss = 56.01948142
# epoch : 96/5000, train loss = 27.34485503, test loss = 55.70436266
# epoch : 97/5000, train loss = 27.15939705, test loss = 56.04539301
# epoch : 98/5000, train loss = 27.18429743, test loss = 56.41382221
# epoch : 99/5000, train loss = 27.31302339, test loss = 56.76601924
# epoch : 100/5000, train loss = 27.42921282, test loss = 55.50583727
# epoch : 101/5000, train loss = 27.27521701, test loss = 55.90861957
# epoch : 102/5000, train loss = 27.46021858, test loss = 55.60100868
# epoch : 103/5000, train loss = 27.63415742, test loss = 57.63181713
# epoch : 104/5000, train loss = 27.14026642, test loss = 56.15012041
# epoch : 105/5000, train loss = 27.17063504, test loss = 55.91892202
# epoch : 106/5000, train loss = 27.17681301, test loss = 55.95242630
# epoch : 107/5000, train loss = 27.13718638, test loss = 56.15451764
# epoch : 108/5000, train loss = 27.22864536, test loss = 55.70478344
# epoch : 109/5000, train loss = 27.63579266, test loss = 55.56589880
# epoch : 110/5000, train loss = 27.12560368, test loss = 55.85423933
# epoch : 111/5000, train loss = 27.21665997, test loss = 55.93277488
# epoch : 112/5000, train loss = 27.26327523, test loss = 56.13999549
# epoch : 113/5000, train loss = 27.17464588, test loss = 56.01624119
# epoch : 114/5000, train loss = 27.45805437, test loss = 55.37303878
# epoch : 115/5000, train loss = 27.25051792, test loss = 56.39655517
# epoch : 116/5000, train loss = 27.21351787, test loss = 55.96892178
# epoch : 117/5000, train loss = 27.20087272, test loss = 56.05732226
# epoch : 118/5000, train loss = 27.18629696, test loss = 55.71849752
# epoch : 119/5000, train loss = 27.12302190, test loss = 55.92934339
# epoch : 120/5000, train loss = 27.11500709, test loss = 56.44365036
# epoch : 121/5000, train loss = 27.40900474, test loss = 56.00209386
# epoch : 122/5000, train loss = 27.25252047, test loss = 56.02840533
# epoch : 123/5000, train loss = 27.08787918, test loss = 55.86665697
# epoch : 124/5000, train loss = 27.17502176, test loss = 55.91716058
# epoch : 125/5000, train loss = 27.16118965, test loss = 56.09369601
# epoch : 126/5000, train loss = 27.06064978, test loss = 55.97181048
# epoch : 127/5000, train loss = 27.10258438, test loss = 55.89238282
# epoch : 128/5000, train loss = 27.12752277, test loss = 55.82125606
# epoch : 129/5000, train loss = 27.24192918, test loss = 56.64510040
# epoch : 130/5000, train loss = 27.08269855, test loss = 55.86332304
# epoch : 131/5000, train loss = 27.14974673, test loss = 56.47096655
# epoch : 132/5000, train loss = 27.10058494, test loss = 55.63375108
# epoch : 133/5000, train loss = 27.21709448, test loss = 56.57947203
# epoch : 134/5000, train loss = 27.72443398, test loss = 57.40392289
# epoch : 135/5000, train loss = 27.38759033, test loss = 55.74524756
# epoch : 136/5000, train loss = 27.35269339, test loss = 56.66139882
# epoch : 137/5000, train loss = 27.20142431, test loss = 56.45683264
# epoch : 138/5000, train loss = 27.51124818, test loss = 55.83614084
# epoch : 139/5000, train loss = 27.27380501, test loss = 55.44036574
# epoch : 140/5000, train loss = 27.10742034, test loss = 56.25343522
# epoch : 141/5000, train loss = 27.18325519, test loss = 56.08821258
# epoch : 142/5000, train loss = 27.30624604, test loss = 57.01925501
# epoch : 143/5000, train loss = 27.08988802, test loss = 55.80055697
# epoch : 144/5000, train loss = 27.08100070, test loss = 56.38059228
# epoch : 145/5000, train loss = 27.11463992, test loss = 55.61072176
# epoch : 146/5000, train loss = 27.52974058, test loss = 57.28055076
# epoch : 147/5000, train loss = 27.42531068, test loss = 55.57543442
# epoch : 148/5000, train loss = 27.05332399, test loss = 56.02086738
# epoch : 149/5000, train loss = 27.05865172, test loss = 56.24761720
# epoch : 150/5000, train loss = 27.43175559, test loss = 56.99117004
# epoch : 151/5000, train loss = 27.05698683, test loss = 56.41605391
# epoch : 152/5000, train loss = 27.12889806, test loss = 55.84564599
# epoch : 153/5000, train loss = 27.32945126, test loss = 57.24814352
# epoch : 154/5000, train loss = 27.39982771, test loss = 55.48180663
# epoch : 155/5000, train loss = 27.81107565, test loss = 55.18644714
# epoch : 156/5000, train loss = 27.04362915, test loss = 56.26176720
# epoch : 157/5000, train loss = 27.07420712, test loss = 56.21796914
# epoch : 158/5000, train loss = 27.13468636, test loss = 56.55165337
# epoch : 159/5000, train loss = 27.01833550, test loss = 56.01213065
# epoch : 160/5000, train loss = 27.58718178, test loss = 57.74421021
# epoch : 161/5000, train loss = 27.02974921, test loss = 56.09833278
# epoch : 162/5000, train loss = 27.13170210, test loss = 56.69612139
# epoch : 163/5000, train loss = 27.00656238, test loss = 56.01372115
# epoch : 164/5000, train loss = 27.34498931, test loss = 57.20510430
# epoch : 165/5000, train loss = 27.10975448, test loss = 55.59852024
# epoch : 166/5000, train loss = 27.14014292, test loss = 56.60913610
# epoch : 167/5000, train loss = 27.22493653, test loss = 56.84915390
# epoch : 168/5000, train loss = 27.02256867, test loss = 56.31668329
# epoch : 169/5000, train loss = 26.99487713, test loss = 56.36017037
# epoch : 170/5000, train loss = 27.32742795, test loss = 55.44638361
# epoch : 171/5000, train loss = 26.97265961, test loss = 56.26550496
# epoch : 172/5000, train loss = 27.01618331, test loss = 56.34389261
# epoch : 173/5000, train loss = 26.97610406, test loss = 56.01326551
# epoch : 174/5000, train loss = 26.97325516, test loss = 56.20703954
# epoch : 175/5000, train loss = 27.25075409, test loss = 57.13156200
# epoch : 176/5000, train loss = 26.98391348, test loss = 56.18536374
# epoch : 177/5000, train loss = 27.22422485, test loss = 55.90468775
# epoch : 178/5000, train loss = 27.21622687, test loss = 56.56229080
# epoch : 179/5000, train loss = 27.39799865, test loss = 57.13165143
# epoch : 180/5000, train loss = 27.41102479, test loss = 55.72882088
# epoch : 181/5000, train loss = 27.10626527, test loss = 56.79122078
# epoch : 182/5000, train loss = 27.12624176, test loss = 55.48803937
# epoch : 183/5000, train loss = 27.13611290, test loss = 55.42526504
# epoch : 184/5000, train loss = 27.29261364, test loss = 57.10681272
# epoch : 185/5000, train loss = 26.97422987, test loss = 56.05164164
# epoch : 186/5000, train loss = 26.98029111, test loss = 56.11621746
# epoch : 187/5000, train loss = 27.26679486, test loss = 55.31650225
# epoch : 188/5000, train loss = 26.99863925, test loss = 56.25510230
# epoch : 189/5000, train loss = 27.10297554, test loss = 55.72773223
# epoch : 190/5000, train loss = 26.99807140, test loss = 55.84195153
# epoch : 191/5000, train loss = 26.96335753, test loss = 56.39737990
# epoch : 192/5000, train loss = 26.98171789, test loss = 55.72644900
# epoch : 193/5000, train loss = 26.94080790, test loss = 56.18922063
# epoch : 194/5000, train loss = 27.18203068, test loss = 55.60434153
# epoch : 195/5000, train loss = 27.48510472, test loss = 57.55701757
# epoch : 196/5000, train loss = 27.12245818, test loss = 55.68846451
# epoch : 197/5000, train loss = 26.91859506, test loss = 56.30683255
# epoch : 198/5000, train loss = 27.02373672, test loss = 56.44830292
# epoch : 199/5000, train loss = 27.08574770, test loss = 56.70683057
# epoch : 200/5000, train loss = 27.02959933, test loss = 55.68182229
# epoch : 201/5000, train loss = 27.20766750, test loss = 56.93043158
# epoch : 202/5000, train loss = 27.29090384, test loss = 55.78720560
# epoch : 203/5000, train loss = 26.87707836, test loss = 55.91157418
# epoch : 204/5000, train loss = 27.33253399, test loss = 55.30814967
# epoch : 205/5000, train loss = 27.17859784, test loss = 57.02998897
# epoch : 206/5000, train loss = 26.88852321, test loss = 56.04360154
# epoch : 207/5000, train loss = 27.02333293, test loss = 56.67387788
# epoch : 208/5000, train loss = 27.14895382, test loss = 56.79440368
# epoch : 209/5000, train loss = 27.12163029, test loss = 55.49789526
# epoch : 210/5000, train loss = 26.98113688, test loss = 56.31743936
# epoch : 211/5000, train loss = 27.41166950, test loss = 55.43442991
# epoch : 212/5000, train loss = 26.89153634, test loss = 55.95562861
# epoch : 213/5000, train loss = 27.05620540, test loss = 56.71553104
# epoch : 214/5000, train loss = 26.91827793, test loss = 56.11719896
# epoch : 215/5000, train loss = 26.92766032, test loss = 56.57409683
# epoch : 216/5000, train loss = 27.05684375, test loss = 55.87163683
# epoch : 217/5000, train loss = 26.89892743, test loss = 56.20056908
# epoch : 218/5000, train loss = 27.55338073, test loss = 54.97433098
# epoch : 219/5000, train loss = 26.96156163, test loss = 55.44496940
# epoch : 220/5000, train loss = 27.04807745, test loss = 55.43515575
# epoch : 221/5000, train loss = 27.00963960, test loss = 56.79469782
# epoch : 222/5000, train loss = 26.90958196, test loss = 56.43919160
# epoch : 223/5000, train loss = 26.91282612, test loss = 56.38838129
# epoch : 224/5000, train loss = 26.85083892, test loss = 56.22074136
# epoch : 225/5000, train loss = 26.91920719, test loss = 55.73406736
# epoch : 226/5000, train loss = 27.15439579, test loss = 57.17765583
# epoch : 227/5000, train loss = 26.87278239, test loss = 56.13086641
# epoch : 228/5000, train loss = 26.83799539, test loss = 56.12877509
# epoch : 229/5000, train loss = 26.92469358, test loss = 55.76564847
# epoch : 230/5000, train loss = 26.86220056, test loss = 56.02188260
# epoch : 231/5000, train loss = 27.34747055, test loss = 55.61364149
# epoch : 232/5000, train loss = 27.27592561, test loss = 55.64945993
# epoch : 233/5000, train loss = 27.10913039, test loss = 55.65825399
# epoch : 234/5000, train loss = 27.15750501, test loss = 55.47736556
# epoch : 235/5000, train loss = 27.15030824, test loss = 57.15604692
# epoch : 236/5000, train loss = 26.83220165, test loss = 56.17913400
# epoch : 237/5000, train loss = 27.06694515, test loss = 55.49021408
# epoch : 238/5000, train loss = 26.86707822, test loss = 56.19090089
# epoch : 239/5000, train loss = 26.90456287, test loss = 55.79774821
# epoch : 240/5000, train loss = 26.92973008, test loss = 55.91921800
# epoch : 241/5000, train loss = 26.84587298, test loss = 55.77363616
# epoch : 242/5000, train loss = 26.96876081, test loss = 56.66222334
# epoch : 243/5000, train loss = 26.82145138, test loss = 56.28570047
# epoch : 244/5000, train loss = 26.86613187, test loss = 56.53860699
# epoch : 245/5000, train loss = 26.91425631, test loss = 56.41682937
# epoch : 246/5000, train loss = 27.14500794, test loss = 55.66398809
# epoch : 247/5000, train loss = 27.10558507, test loss = 56.88462761
# epoch : 248/5000, train loss = 26.83927620, test loss = 56.15776566
# epoch : 249/5000, train loss = 26.95576066, test loss = 55.93151879
# epoch : 250/5000, train loss = 26.90667205, test loss = 55.58995764
# epoch : 251/5000, train loss = 26.81014948, test loss = 55.79716358
# epoch : 252/5000, train loss = 26.83170490, test loss = 56.37500490
# epoch : 253/5000, train loss = 26.83493126, test loss = 56.16797606
# epoch : 254/5000, train loss = 26.97049035, test loss = 56.92536858
# epoch : 255/5000, train loss = 27.11409598, test loss = 55.84019599
# epoch : 256/5000, train loss = 26.79124461, test loss = 55.95728486
# epoch : 257/5000, train loss = 26.79259655, test loss = 55.88197423
# epoch : 258/5000, train loss = 26.80968140, test loss = 55.66619868
# epoch : 259/5000, train loss = 26.85330232, test loss = 56.40648283
# epoch : 260/5000, train loss = 26.78685539, test loss = 56.31930883
# epoch : 261/5000, train loss = 27.12071267, test loss = 57.06791408
# epoch : 262/5000, train loss = 26.89744866, test loss = 56.70967915
# epoch : 263/5000, train loss = 27.10821416, test loss = 55.58483409
# epoch : 264/5000, train loss = 26.79448647, test loss = 56.14042152
# epoch : 265/5000, train loss = 26.94481255, test loss = 55.55325526
# epoch : 266/5000, train loss = 26.80169232, test loss = 55.86025302
# epoch : 267/5000, train loss = 26.79570821, test loss = 55.81271543
# epoch : 268/5000, train loss = 27.04758652, test loss = 55.65440844
# epoch : 269/5000, train loss = 27.08136580, test loss = 55.53705798
# epoch : 270/5000, train loss = 26.80945435, test loss = 55.91775769
# epoch : 271/5000, train loss = 26.79554789, test loss = 56.04989704
# epoch : 272/5000, train loss = 26.80051351, test loss = 56.12116578
# epoch : 273/5000, train loss = 26.87104896, test loss = 56.69297431
# epoch : 274/5000, train loss = 27.03477218, test loss = 55.70739824
# epoch : 275/5000, train loss = 26.90693366, test loss = 55.61860626
# epoch : 276/5000, train loss = 27.07426836, test loss = 57.07034252
# epoch : 277/5000, train loss = 27.07115213, test loss = 55.90297375
# epoch : 278/5000, train loss = 26.79457969, test loss = 55.90244181
# epoch : 279/5000, train loss = 27.11665476, test loss = 57.29596715
# epoch : 280/5000, train loss = 26.71014962, test loss = 56.15120888
# epoch : 281/5000, train loss = 26.99255205, test loss = 55.88343997
# epoch : 282/5000, train loss = 26.90000017, test loss = 55.81489365
# epoch : 283/5000, train loss = 26.75138959, test loss = 55.98834517
# epoch : 284/5000, train loss = 26.93004932, test loss = 55.83699345
# epoch : 285/5000, train loss = 27.12835378, test loss = 55.53943067
# epoch : 286/5000, train loss = 26.74810195, test loss = 55.81035045
# epoch : 287/5000, train loss = 27.01283490, test loss = 57.06822501
# epoch : 288/5000, train loss = 26.72161629, test loss = 56.37779965
# epoch : 289/5000, train loss = 26.74527242, test loss = 56.14160146
# epoch : 290/5000, train loss = 26.93910528, test loss = 55.60849574
# epoch : 291/5000, train loss = 26.87889287, test loss = 56.51023017
# epoch : 292/5000, train loss = 26.74898177, test loss = 55.69536220
# epoch : 293/5000, train loss = 26.67921254, test loss = 56.13330070
# epoch : 294/5000, train loss = 26.77658533, test loss = 55.72534824
# epoch : 295/5000, train loss = 26.71239608, test loss = 56.19541240
# epoch : 296/5000, train loss = 26.81207970, test loss = 55.77042994
# epoch : 297/5000, train loss = 26.67609716, test loss = 56.01950704
# epoch : 298/5000, train loss = 26.80750552, test loss = 56.67056440
# epoch : 299/5000, train loss = 26.78603662, test loss = 56.65861686
# epoch : 300/5000, train loss = 26.86124089, test loss = 55.88914316
# epoch : 301/5000, train loss = 26.84040939, test loss = 56.84139341
# epoch : 302/5000, train loss = 26.67513130, test loss = 56.04179810
# epoch : 303/5000, train loss = 26.76247952, test loss = 55.75269689
# epoch : 304/5000, train loss = 26.70279965, test loss = 55.76978117
# epoch : 305/5000, train loss = 26.69180524, test loss = 56.18274907
# epoch : 306/5000, train loss = 26.89009904, test loss = 56.52789239
# epoch : 307/5000, train loss = 26.71669094, test loss = 56.28311612
# epoch : 308/5000, train loss = 26.77734541, test loss = 55.69112457
# epoch : 309/5000, train loss = 26.69582987, test loss = 56.23096299
# epoch : 310/5000, train loss = 26.75753406, test loss = 55.90908928
# epoch : 311/5000, train loss = 26.64061966, test loss = 56.07136546
# epoch : 312/5000, train loss = 26.78811114, test loss = 56.78142865
# epoch : 313/5000, train loss = 26.70371399, test loss = 55.73072479
# epoch : 314/5000, train loss = 26.75222774, test loss = 56.41619817
# epoch : 315/5000, train loss = 27.03279866, test loss = 55.67468383
# epoch : 316/5000, train loss = 26.65772889, test loss = 56.03071345
# epoch : 317/5000, train loss = 27.21725109, test loss = 57.32238226
# epoch : 318/5000, train loss = 26.68275315, test loss = 56.36603106
# epoch : 319/5000, train loss = 26.66651530, test loss = 56.06408007
# epoch : 320/5000, train loss = 26.77149055, test loss = 55.84822867
# epoch : 321/5000, train loss = 26.67446891, test loss = 56.44476230
# epoch : 322/5000, train loss = 26.66383784, test loss = 55.85075677
# epoch : 323/5000, train loss = 26.68572423, test loss = 56.28053930
# epoch : 324/5000, train loss = 26.66004439, test loss = 55.94537834
# epoch : 325/5000, train loss = 27.01806654, test loss = 55.57974684
# epoch : 326/5000, train loss = 26.69966969, test loss = 55.89752053
# epoch : 327/5000, train loss = 26.68348919, test loss = 56.62347548
# epoch : 328/5000, train loss = 26.64873134, test loss = 56.38373382
# epoch : 329/5000, train loss = 26.64815965, test loss = 56.03627760
# epoch : 330/5000, train loss = 26.66261040, test loss = 55.86166059
# epoch : 331/5000, train loss = 26.70423808, test loss = 56.58699620
# epoch : 332/5000, train loss = 26.81231946, test loss = 56.82980826
# epoch : 333/5000, train loss = 26.70510052, test loss = 55.86939164
# epoch : 334/5000, train loss = 27.12966093, test loss = 55.46587414
# epoch : 335/5000, train loss = 26.61081236, test loss = 56.01303014
# epoch : 336/5000, train loss = 26.61411412, test loss = 56.44200404
# epoch : 337/5000, train loss = 26.70865513, test loss = 56.53154334
# epoch : 338/5000, train loss = 26.61153053, test loss = 55.79821672
# epoch : 339/5000, train loss = 26.65222728, test loss = 55.96910802
# epoch : 340/5000, train loss = 26.61660205, test loss = 56.41790127
# epoch : 341/5000, train loss = 26.92873601, test loss = 57.17053284
# epoch : 342/5000, train loss = 26.67199275, test loss = 56.14297853
# epoch : 343/5000, train loss = 26.59409337, test loss = 56.12529686
# epoch : 344/5000, train loss = 26.77128330, test loss = 55.45508914
# epoch : 345/5000, train loss = 26.76962187, test loss = 55.40147414
# epoch : 346/5000, train loss = 26.94958845, test loss = 57.28203905
# epoch : 347/5000, train loss = 26.64128369, test loss = 56.40732647
# epoch : 348/5000, train loss = 27.30352080, test loss = 55.61853883
# epoch : 349/5000, train loss = 26.74411380, test loss = 56.47009675
# epoch : 350/5000, train loss = 27.23564510, test loss = 57.77578614
# epoch : 351/5000, train loss = 26.91415977, test loss = 56.86589942
# epoch : 352/5000, train loss = 26.68356092, test loss = 56.47870298
# epoch : 353/5000, train loss = 26.62847946, test loss = 56.51502276
# epoch : 354/5000, train loss = 26.64465590, test loss = 56.39483391
# epoch : 355/5000, train loss = 26.76457989, test loss = 55.67847008
# epoch : 356/5000, train loss = 26.58877390, test loss = 55.81959091
# epoch : 357/5000, train loss = 26.79602455, test loss = 55.61758313
# epoch : 358/5000, train loss = 26.64509006, test loss = 55.80607528
# epoch : 359/5000, train loss = 26.68536957, test loss = 55.77480897
# epoch : 360/5000, train loss = 26.76154420, test loss = 56.74491876
# epoch : 361/5000, train loss = 26.70331135, test loss = 56.02233397
# epoch : 362/5000, train loss = 26.61560133, test loss = 55.86871398
# epoch : 363/5000, train loss = 26.58786348, test loss = 56.28694490
# epoch : 364/5000, train loss = 26.62287665, test loss = 56.44916168
# epoch : 365/5000, train loss = 26.55133906, test loss = 56.25021490
# epoch : 366/5000, train loss = 26.54442242, test loss = 56.20262258
# epoch : 367/5000, train loss = 26.66558119, test loss = 55.76969929
# epoch : 368/5000, train loss = 26.66425857, test loss = 56.71952287
# epoch : 369/5000, train loss = 26.70993137, test loss = 55.94633001
# epoch : 370/5000, train loss = 26.78413500, test loss = 56.99457793
# epoch : 371/5000, train loss = 26.60470375, test loss = 56.59016913
# epoch : 372/5000, train loss = 26.55015019, test loss = 56.39888220
# epoch : 373/5000, train loss = 26.77230497, test loss = 56.86174637
# epoch : 374/5000, train loss = 26.75850206, test loss = 56.76551942
# epoch : 375/5000, train loss = 26.96592017, test loss = 55.59676779
# epoch : 376/5000, train loss = 26.55082917, test loss = 55.85248439
# epoch : 377/5000, train loss = 26.59845050, test loss = 56.62812540
# epoch : 378/5000, train loss = 26.54852226, test loss = 56.38465088
# epoch : 379/5000, train loss = 26.81738543, test loss = 55.60505155
# epoch : 380/5000, train loss = 26.53322344, test loss = 55.91825974
# epoch : 381/5000, train loss = 26.55931118, test loss = 55.80098599
# epoch : 382/5000, train loss = 26.55170770, test loss = 56.37167960
# epoch : 383/5000, train loss = 26.63437465, test loss = 56.54993841
# epoch : 384/5000, train loss = 26.51356014, test loss = 56.21134637
# epoch : 385/5000, train loss = 26.63420308, test loss = 56.57794399
# epoch : 386/5000, train loss = 26.62457002, test loss = 56.51425935
# epoch : 387/5000, train loss = 26.50369001, test loss = 56.26079682
# epoch : 388/5000, train loss = 26.56544400, test loss = 56.20847422
# epoch : 389/5000, train loss = 26.50846939, test loss = 56.12274309
# epoch : 390/5000, train loss = 26.54217824, test loss = 56.41601761
# epoch : 391/5000, train loss = 26.50320711, test loss = 55.89604917
# epoch : 392/5000, train loss = 26.53280717, test loss = 55.72745961
# epoch : 393/5000, train loss = 26.56352976, test loss = 56.44394119
# epoch : 394/5000, train loss = 26.84588412, test loss = 57.12877155
# epoch : 395/5000, train loss = 26.53109281, test loss = 56.35713946
# epoch : 396/5000, train loss = 26.54148749, test loss = 56.17121181
# epoch : 397/5000, train loss = 26.48319860, test loss = 56.04712953
# epoch : 398/5000, train loss = 26.56532237, test loss = 56.50165306
# epoch : 399/5000, train loss = 26.60563076, test loss = 56.56051165
# epoch : 400/5000, train loss = 26.58975614, test loss = 56.36279746
# epoch : 401/5000, train loss = 26.50534449, test loss = 55.94639200
# epoch : 402/5000, train loss = 26.52572285, test loss = 56.38474297
# epoch : 403/5000, train loss = 26.52851266, test loss = 55.77072518
# epoch : 404/5000, train loss = 26.50232888, test loss = 55.84609629
# epoch : 405/5000, train loss = 26.60377039, test loss = 56.77060579
# epoch : 406/5000, train loss = 26.50816542, test loss = 56.05970224
# epoch : 407/5000, train loss = 26.60512643, test loss = 55.59844890
# epoch : 408/5000, train loss = 26.55690038, test loss = 56.35862234
# epoch : 409/5000, train loss = 26.47588698, test loss = 55.89758682
# epoch : 410/5000, train loss = 26.45018110, test loss = 56.20816433
# epoch : 411/5000, train loss = 26.46038024, test loss = 55.99926807
# epoch : 412/5000, train loss = 26.55240969, test loss = 55.75274441
# epoch : 413/5000, train loss = 26.88561584, test loss = 55.55878087
# epoch : 414/5000, train loss = 26.49599616, test loss = 55.95289694
# epoch : 415/5000, train loss = 26.44952105, test loss = 56.04532167
# epoch : 416/5000, train loss = 26.64280762, test loss = 55.51415262
# epoch : 417/5000, train loss = 26.50153939, test loss = 55.80684201
# epoch : 418/5000, train loss = 26.79955175, test loss = 56.86600166
# epoch : 419/5000, train loss = 26.54066700, test loss = 56.39278177
# epoch : 420/5000, train loss = 26.53846229, test loss = 55.96739933
# epoch : 421/5000, train loss = 26.61975642, test loss = 56.73572758
# epoch : 422/5000, train loss = 26.69172108, test loss = 56.90433227
# epoch : 423/5000, train loss = 27.31010656, test loss = 57.86531643
# epoch : 424/5000, train loss = 26.71416877, test loss = 57.02877969
# epoch : 425/5000, train loss = 26.44983619, test loss = 55.94762208
# epoch : 426/5000, train loss = 26.48579508, test loss = 56.06368997
# epoch : 427/5000, train loss = 26.42162137, test loss = 56.11961696
# epoch : 428/5000, train loss = 26.43786976, test loss = 56.27162793
# epoch : 429/5000, train loss = 26.52734072, test loss = 55.79706669
# epoch : 430/5000, train loss = 26.52464796, test loss = 56.47687745
# epoch : 431/5000, train loss = 26.49914175, test loss = 55.72839168
# epoch : 432/5000, train loss = 26.41518601, test loss = 56.25403360
# epoch : 433/5000, train loss = 26.42019267, test loss = 56.21332864
# epoch : 434/5000, train loss = 26.44200016, test loss = 55.79351329
# epoch : 435/5000, train loss = 26.48183253, test loss = 56.43420248
# epoch : 436/5000, train loss = 26.40460302, test loss = 56.03907211
# epoch : 437/5000, train loss = 26.75350933, test loss = 55.64556987
# epoch : 438/5000, train loss = 26.45699706, test loss = 56.45429566
# epoch : 439/5000, train loss = 26.68033936, test loss = 56.71934042
# epoch : 440/5000, train loss = 26.42166417, test loss = 56.01834484
# epoch : 441/5000, train loss = 26.51426902, test loss = 55.80281802
# epoch : 442/5000, train loss = 26.60032946, test loss = 55.93372402
# epoch : 443/5000, train loss = 26.44067676, test loss = 55.86454249
# epoch : 444/5000, train loss = 26.46057430, test loss = 56.45160887
# epoch : 445/5000, train loss = 26.39171490, test loss = 56.07486282
# epoch : 446/5000, train loss = 26.38809003, test loss = 56.04957480
# epoch : 447/5000, train loss = 26.47820389, test loss = 55.76300228
# epoch : 448/5000, train loss = 26.41463442, test loss = 56.40619116
# epoch : 449/5000, train loss = 26.40824818, test loss = 56.05420187
# epoch : 450/5000, train loss = 26.41505506, test loss = 55.85189559
# epoch : 451/5000, train loss = 26.37663591, test loss = 55.95135450
# epoch : 452/5000, train loss = 26.42241984, test loss = 55.85552677
# epoch : 453/5000, train loss = 26.37572345, test loss = 55.84379196
# epoch : 454/5000, train loss = 26.43713046, test loss = 56.31739626
# epoch : 455/5000, train loss = 26.44022985, test loss = 55.92318233
# epoch : 456/5000, train loss = 26.47935260, test loss = 55.79331606
# epoch : 457/5000, train loss = 26.38168223, test loss = 56.01640778
# epoch : 458/5000, train loss = 26.41788638, test loss = 55.98846340
# epoch : 459/5000, train loss = 26.43918142, test loss = 56.45471063
# epoch : 460/5000, train loss = 26.40666657, test loss = 56.21786499
# epoch : 461/5000, train loss = 26.42101718, test loss = 55.80567262
# epoch : 462/5000, train loss = 26.37188952, test loss = 56.09767775
# epoch : 463/5000, train loss = 26.63543349, test loss = 55.50108201
# epoch : 464/5000, train loss = 26.76834804, test loss = 57.25045286
# epoch : 465/5000, train loss = 26.36493570, test loss = 55.97774660
# epoch : 466/5000, train loss = 26.35269791, test loss = 56.02228824
# epoch : 467/5000, train loss = 26.41687486, test loss = 56.46768386
# epoch : 468/5000, train loss = 26.35795683, test loss = 55.91396603
# epoch : 469/5000, train loss = 26.34657691, test loss = 56.04154056
# epoch : 470/5000, train loss = 26.37086764, test loss = 55.88777429
# epoch : 471/5000, train loss = 26.38530930, test loss = 55.73282946
# epoch : 472/5000, train loss = 26.56073710, test loss = 56.78860067
# epoch : 473/5000, train loss = 26.35990468, test loss = 56.06263735
# epoch : 474/5000, train loss = 26.38182483, test loss = 55.85310406
# epoch : 475/5000, train loss = 26.40890057, test loss = 55.95925994
# epoch : 476/5000, train loss = 26.37706354, test loss = 56.29277593
# epoch : 477/5000, train loss = 26.34599844, test loss = 55.91626516
# epoch : 478/5000, train loss = 26.33790577, test loss = 56.06292422
# epoch : 479/5000, train loss = 26.34995499, test loss = 55.90733402
# epoch : 480/5000, train loss = 26.34847278, test loss = 55.87764473
# epoch : 481/5000, train loss = 26.38794917, test loss = 55.98638896
# epoch : 482/5000, train loss = 26.38723681, test loss = 55.96427434
# epoch : 483/5000, train loss = 26.48003472, test loss = 55.63107994
# epoch : 484/5000, train loss = 26.36509041, test loss = 55.93509031
# epoch : 485/5000, train loss = 26.35069845, test loss = 56.24229074
# epoch : 486/5000, train loss = 26.36384866, test loss = 56.43725541
# epoch : 487/5000, train loss = 26.51626345, test loss = 55.58311019
# epoch : 488/5000, train loss = 26.45287038, test loss = 56.49258092
# epoch : 489/5000, train loss = 26.37755089, test loss = 55.87580413
# epoch : 490/5000, train loss = 26.42322823, test loss = 56.61378444
# epoch : 491/5000, train loss = 26.36503364, test loss = 55.86849949
# epoch : 492/5000, train loss = 26.31043573, test loss = 55.83774041
# epoch : 493/5000, train loss = 26.31136850, test loss = 56.02687423
# epoch : 494/5000, train loss = 26.30530777, test loss = 55.98756328
# epoch : 495/5000, train loss = 26.32962810, test loss = 56.30932493
# epoch : 496/5000, train loss = 26.34997544, test loss = 55.84714992
# epoch : 497/5000, train loss = 26.37490861, test loss = 55.68553986
# epoch : 498/5000, train loss = 26.35921132, test loss = 56.20892724
# epoch : 499/5000, train loss = 26.32197558, test loss = 56.27972741
# epoch : 500/5000, train loss = 26.36774854, test loss = 56.50583150
# epoch : 501/5000, train loss = 26.30680632, test loss = 56.12599754
# epoch : 502/5000, train loss = 26.35643120, test loss = 56.41881577
# epoch : 503/5000, train loss = 26.29455701, test loss = 55.87099396
# epoch : 504/5000, train loss = 26.38729257, test loss = 56.44285624
# epoch : 505/5000, train loss = 26.28995723, test loss = 56.20430369
# epoch : 506/5000, train loss = 26.34301233, test loss = 56.10400134
# epoch : 507/5000, train loss = 26.69047288, test loss = 57.29680959
# epoch : 508/5000, train loss = 26.35714952, test loss = 56.39872476
# epoch : 509/5000, train loss = 26.32483522, test loss = 56.18317167
# epoch : 510/5000, train loss = 26.28999735, test loss = 55.98183486
# epoch : 511/5000, train loss = 26.31431747, test loss = 56.19385832
# epoch : 512/5000, train loss = 26.42397210, test loss = 56.29549620
# epoch : 513/5000, train loss = 26.41124217, test loss = 55.77994586
# epoch : 514/5000, train loss = 26.27303662, test loss = 56.08747525
# epoch : 515/5000, train loss = 26.27933085, test loss = 56.14627964
# epoch : 516/5000, train loss = 26.28003975, test loss = 56.25848405
# epoch : 517/5000, train loss = 26.35226371, test loss = 56.04532716
# epoch : 518/5000, train loss = 26.53497700, test loss = 55.62049157
# epoch : 519/5000, train loss = 26.28553888, test loss = 56.25380888
# epoch : 520/5000, train loss = 26.38495329, test loss = 56.16660394
# epoch : 521/5000, train loss = 26.47933111, test loss = 56.93437337
# epoch : 522/5000, train loss = 26.37653098, test loss = 55.79718030
# epoch : 523/5000, train loss = 26.28886928, test loss = 56.20536417
# epoch : 524/5000, train loss = 26.29925257, test loss = 55.76246761
# epoch : 525/5000, train loss = 26.33399845, test loss = 55.69273797
# epoch : 526/5000, train loss = 26.29318595, test loss = 55.84800691
# epoch : 527/5000, train loss = 26.31425328, test loss = 56.35801847
# epoch : 528/5000, train loss = 26.34996954, test loss = 56.41034765
# epoch : 529/5000, train loss = 26.33897147, test loss = 55.80777296
# epoch : 530/5000, train loss = 26.29025854, test loss = 55.72546312
# epoch : 531/5000, train loss = 26.40345326, test loss = 55.53881112
# epoch : 532/5000, train loss = 26.32744923, test loss = 55.66376406
# epoch : 533/5000, train loss = 26.54253297, test loss = 55.50823451
# epoch : 534/5000, train loss = 26.26097280, test loss = 56.10248225
# epoch : 535/5000, train loss = 26.44362696, test loss = 55.64610495
# epoch : 536/5000, train loss = 26.86953472, test loss = 55.37620445
# epoch : 537/5000, train loss = 26.33839130, test loss = 55.79420794
# epoch : 538/5000, train loss = 26.41375397, test loss = 56.77777771
# epoch : 539/5000, train loss = 26.27899889, test loss = 56.18213240
# epoch : 540/5000, train loss = 26.26651792, test loss = 56.27855816
# epoch : 541/5000, train loss = 26.26206569, test loss = 55.75724971
# epoch : 542/5000, train loss = 26.43683404, test loss = 56.69757263
# epoch : 543/5000, train loss = 26.27519189, test loss = 55.85219824
# epoch : 544/5000, train loss = 26.25417341, test loss = 56.10546865
# epoch : 545/5000, train loss = 26.25802408, test loss = 56.28775776
# epoch : 546/5000, train loss = 26.32664554, test loss = 56.38938424
# epoch : 547/5000, train loss = 26.27760338, test loss = 55.63842006
# epoch : 548/5000, train loss = 26.23305104, test loss = 56.20019908
# epoch : 549/5000, train loss = 26.23855905, test loss = 55.82608842
# epoch : 550/5000, train loss = 26.22558743, test loss = 56.09337166
# epoch : 551/5000, train loss = 26.45657531, test loss = 55.64665877
# epoch : 552/5000, train loss = 26.30246790, test loss = 55.74907905
# epoch : 553/5000, train loss = 26.29628213, test loss = 56.14746940
# epoch : 554/5000, train loss = 26.24035790, test loss = 55.94348698
# epoch : 555/5000, train loss = 26.39060901, test loss = 56.69654390
# epoch : 556/5000, train loss = 26.33907599, test loss = 56.62119352
# epoch : 557/5000, train loss = 26.26986881, test loss = 56.19513435
# epoch : 558/5000, train loss = 26.32480818, test loss = 56.40634421
# epoch : 559/5000, train loss = 26.23147473, test loss = 55.91584405
# epoch : 560/5000, train loss = 26.95461032, test loss = 55.25109838
# epoch : 561/5000, train loss = 26.25939275, test loss = 55.79214860
# epoch : 562/5000, train loss = 26.21305451, test loss = 55.91111557
# epoch : 563/5000, train loss = 26.54485487, test loss = 57.17498995
# epoch : 564/5000, train loss = 26.81721362, test loss = 55.40039798
# epoch : 565/5000, train loss = 26.23855890, test loss = 56.15486881
# epoch : 566/5000, train loss = 26.28194170, test loss = 56.09967369
# epoch : 567/5000, train loss = 26.27390078, test loss = 55.71098771
# epoch : 568/5000, train loss = 26.22041479, test loss = 55.94937944
# epoch : 569/5000, train loss = 26.41877953, test loss = 56.84377902
# epoch : 570/5000, train loss = 26.27513180, test loss = 56.60681656
# epoch : 571/5000, train loss = 26.27316637, test loss = 56.54861142
# epoch : 572/5000, train loss = 26.44280523, test loss = 56.84051756
# epoch : 573/5000, train loss = 26.19134274, test loss = 56.13898314
# epoch : 574/5000, train loss = 26.20944148, test loss = 56.27582221
# epoch : 575/5000, train loss = 26.19167892, test loss = 55.87608283
# epoch : 576/5000, train loss = 26.31000319, test loss = 56.57930232
# epoch : 577/5000, train loss = 26.20898993, test loss = 55.75870029
# epoch : 578/5000, train loss = 26.32067083, test loss = 55.65302289
# epoch : 579/5000, train loss = 26.21561807, test loss = 56.03180650
# epoch : 580/5000, train loss = 26.40077266, test loss = 55.50230402
# epoch : 581/5000, train loss = 26.27481179, test loss = 55.61911935
# epoch : 582/5000, train loss = 26.31573783, test loss = 56.60952090
# epoch : 583/5000, train loss = 26.24773043, test loss = 56.31238788
# epoch : 584/5000, train loss = 26.28302656, test loss = 55.61910902
# epoch : 585/5000, train loss = 26.40637909, test loss = 56.82706540
# epoch : 586/5000, train loss = 26.20391505, test loss = 56.06341499
# epoch : 587/5000, train loss = 26.24128643, test loss = 56.26033589
# epoch : 588/5000, train loss = 26.42389645, test loss = 55.52719708
# epoch : 589/5000, train loss = 26.16320161, test loss = 56.07266638
# epoch : 590/5000, train loss = 26.16690049, test loss = 55.98264761
# epoch : 591/5000, train loss = 26.14593684, test loss = 55.99981814
# epoch : 592/5000, train loss = 26.17509134, test loss = 55.84336335
# epoch : 593/5000, train loss = 26.15507723, test loss = 55.98672713
# epoch : 594/5000, train loss = 26.15006994, test loss = 55.97801580
# epoch : 595/5000, train loss = 26.17593211, test loss = 56.24044025
# epoch : 596/5000, train loss = 26.15236507, test loss = 55.85745631
# epoch : 597/5000, train loss = 26.15352508, test loss = 56.10745088
# epoch : 598/5000, train loss = 26.19315043, test loss = 55.91008557
# epoch : 599/5000, train loss = 26.38129699, test loss = 55.46394021
# epoch : 600/5000, train loss = 26.26398575, test loss = 55.62631058
# epoch : 601/5000, train loss = 26.31649973, test loss = 55.63085166
# epoch : 602/5000, train loss = 26.14590756, test loss = 55.78472050
# epoch : 603/5000, train loss = 26.18181127, test loss = 56.26580519
# epoch : 604/5000, train loss = 26.56374191, test loss = 55.39898772
# epoch : 605/5000, train loss = 26.15117214, test loss = 55.93402522
# epoch : 606/5000, train loss = 26.16652362, test loss = 55.87552032
# epoch : 607/5000, train loss = 26.30002470, test loss = 56.70562041
# epoch : 608/5000, train loss = 26.20476838, test loss = 55.72074194
# epoch : 609/5000, train loss = 26.23117259, test loss = 55.76585741
# epoch : 610/5000, train loss = 26.17335736, test loss = 56.28186987
# epoch : 611/5000, train loss = 26.18960372, test loss = 56.06105319
# epoch : 612/5000, train loss = 26.14291124, test loss = 55.85681276
# epoch : 613/5000, train loss = 26.17810424, test loss = 55.80956221
# epoch : 614/5000, train loss = 26.17628660, test loss = 55.86835111
# epoch : 615/5000, train loss = 26.12858853, test loss = 56.09425079
# epoch : 616/5000, train loss = 26.11964482, test loss = 56.05698517
# epoch : 617/5000, train loss = 26.20790961, test loss = 56.52383031
# epoch : 618/5000, train loss = 26.12491440, test loss = 56.13844931
# epoch : 619/5000, train loss = 26.17537664, test loss = 56.23096556
# epoch : 620/5000, train loss = 26.12430543, test loss = 56.03630888
# epoch : 621/5000, train loss = 26.20010862, test loss = 56.17649640
# epoch : 622/5000, train loss = 26.13737063, test loss = 56.18794669
# epoch : 623/5000, train loss = 26.18542792, test loss = 55.53041653
# epoch : 624/5000, train loss = 26.18050447, test loss = 55.63552762
# epoch : 625/5000, train loss = 26.12372640, test loss = 56.04528189
# epoch : 626/5000, train loss = 26.14746657, test loss = 56.15856860
# epoch : 627/5000, train loss = 26.12927218, test loss = 55.75355736
# epoch : 628/5000, train loss = 26.14387548, test loss = 55.96783201
# epoch : 629/5000, train loss = 26.15739253, test loss = 55.71698402
# epoch : 630/5000, train loss = 26.11027166, test loss = 55.93068957
# epoch : 631/5000, train loss = 26.28336284, test loss = 55.51163464
# epoch : 632/5000, train loss = 26.10378427, test loss = 55.90727639
# epoch : 633/5000, train loss = 26.20942681, test loss = 56.29617523
# epoch : 634/5000, train loss = 26.11103262, test loss = 56.09244839
# epoch : 635/5000, train loss = 26.21772172, test loss = 56.38163745
# epoch : 636/5000, train loss = 26.13024093, test loss = 56.08488459
# epoch : 637/5000, train loss = 26.13412452, test loss = 55.73444342
# epoch : 638/5000, train loss = 26.11407111, test loss = 55.79279139
# epoch : 639/5000, train loss = 26.10987384, test loss = 55.90855726
# epoch : 640/5000, train loss = 26.18275567, test loss = 56.38831496
# epoch : 641/5000, train loss = 26.12968462, test loss = 55.83430971
# epoch : 642/5000, train loss = 26.08084842, test loss = 55.93587616
# epoch : 643/5000, train loss = 26.10524772, test loss = 55.83677517
# epoch : 644/5000, train loss = 26.12627146, test loss = 55.74003628
# epoch : 645/5000, train loss = 26.12919470, test loss = 56.22764663
# epoch : 646/5000, train loss = 26.37143276, test loss = 56.94653109
# epoch : 647/5000, train loss = 26.41893889, test loss = 55.36085171
# epoch : 648/5000, train loss = 26.11151636, test loss = 56.18231465
# epoch : 649/5000, train loss = 26.26495806, test loss = 55.70218720
# epoch : 650/5000, train loss = 26.21992148, test loss = 56.61860033
# epoch : 651/5000, train loss = 26.16980340, test loss = 55.75633487
# epoch : 652/5000, train loss = 26.20551702, test loss = 55.70746177
# epoch : 653/5000, train loss = 26.09770111, test loss = 55.78363871
# epoch : 654/5000, train loss = 26.11081389, test loss = 56.22187543
# epoch : 655/5000, train loss = 26.26401121, test loss = 56.68271875
# epoch : 656/5000, train loss = 26.18795731, test loss = 56.59387002
# epoch : 657/5000, train loss = 26.16200846, test loss = 56.52430481
# epoch : 658/5000, train loss = 26.09121164, test loss = 55.95173812
# epoch : 659/5000, train loss = 26.25122223, test loss = 55.66875599
# epoch : 660/5000, train loss = 26.09691268, test loss = 55.98214650
# epoch : 661/5000, train loss = 26.22774446, test loss = 55.46839184
# epoch : 662/5000, train loss = 26.18829909, test loss = 56.32769522
# epoch : 663/5000, train loss = 26.08471151, test loss = 55.74418731
# epoch : 664/5000, train loss = 26.13142966, test loss = 56.33527799
# epoch : 665/5000, train loss = 26.08944968, test loss = 55.75063938
# epoch : 666/5000, train loss = 26.22254942, test loss = 56.65431581
# epoch : 667/5000, train loss = 26.05992660, test loss = 56.16511379
# epoch : 668/5000, train loss = 26.05519281, test loss = 55.89426214
# epoch : 669/5000, train loss = 26.24654972, test loss = 55.60224554
# epoch : 670/5000, train loss = 26.14218665, test loss = 55.68950458
# epoch : 671/5000, train loss = 26.06719753, test loss = 55.92835278
# epoch : 672/5000, train loss = 26.15054672, test loss = 56.53817146
# epoch : 673/5000, train loss = 26.07007490, test loss = 55.78496131
# epoch : 674/5000, train loss = 26.05002040, test loss = 56.00678851
# epoch : 675/5000, train loss = 26.19098185, test loss = 56.50593447
# epoch : 676/5000, train loss = 26.05197733, test loss = 55.99183089
# epoch : 677/5000, train loss = 26.04822836, test loss = 56.09260961
# epoch : 678/5000, train loss = 26.07707553, test loss = 55.75801257
# epoch : 679/5000, train loss = 26.11988165, test loss = 55.83957660
# epoch : 680/5000, train loss = 26.06516937, test loss = 56.18277231
# epoch : 681/5000, train loss = 26.09716341, test loss = 55.62687136
# epoch : 682/5000, train loss = 26.08284421, test loss = 55.82981735
# epoch : 683/5000, train loss = 26.11033258, test loss = 56.35402963
# epoch : 684/5000, train loss = 26.06294899, test loss = 55.93499224
# epoch : 685/5000, train loss = 26.29840041, test loss = 56.89285159
# epoch : 686/5000, train loss = 26.06166918, test loss = 55.91940023
# epoch : 687/5000, train loss = 26.22235607, test loss = 56.72632337
# epoch : 688/5000, train loss = 26.08928327, test loss = 55.76674055
# epoch : 689/5000, train loss = 26.02645937, test loss = 56.09875589
# epoch : 690/5000, train loss = 26.02598027, test loss = 55.96071999
# epoch : 691/5000, train loss = 26.05170240, test loss = 56.24437503
# epoch : 692/5000, train loss = 26.03267176, test loss = 56.14568498
# epoch : 693/5000, train loss = 26.07083230, test loss = 55.70245330
# epoch : 694/5000, train loss = 26.23003128, test loss = 55.51632781
# epoch : 695/5000, train loss = 26.04186009, test loss = 56.00368992
# epoch : 696/5000, train loss = 26.04965832, test loss = 56.09990714
# epoch : 697/5000, train loss = 26.32111776, test loss = 55.44761717
# epoch : 698/5000, train loss = 26.03556647, test loss = 56.09309974
# epoch : 699/5000, train loss = 26.76229793, test loss = 55.20491559
# epoch : 700/5000, train loss = 26.09569592, test loss = 55.70991234
# epoch : 701/5000, train loss = 26.02806514, test loss = 55.74008595
# epoch : 702/5000, train loss = 26.06075269, test loss = 55.85688190
# epoch : 703/5000, train loss = 26.03844164, test loss = 55.91152979
# epoch : 704/5000, train loss = 26.05946563, test loss = 55.62443379
# epoch : 705/5000, train loss = 26.30051236, test loss = 56.91913577
# epoch : 706/5000, train loss = 26.03029678, test loss = 56.13253671
# epoch : 707/5000, train loss = 26.08544070, test loss = 55.75011319
# ...
# epoch : 2842/5000, train loss = 24.93304004, test loss = 55.90623208
# epoch : 2843/5000, train loss = 24.93837161, test loss = 55.86498177
# epoch : 2844/5000, train loss = 24.93521263, test loss = 55.90548196
# epoch : 2845/5000, train loss = 24.93640634, test loss = 55.90279824
# epoch : 2846/5000, train loss = 24.93222840, test loss = 55.94666533
# epoch : 2847/5000, train loss = 24.93136465, test loss = 55.94014205
# epoch : 2848/5000, train loss = 24.93695727, test loss = 56.00572176
# epoch : 2849/5000, train loss = 24.93146280, test loss = 55.91180621
# epoch : 2850/5000, train loss = 24.93515645, test loss = 55.88350400
# epoch : 2851/5000, train loss = 24.93100399, test loss = 55.90904429
# epoch : 2852/5000, train loss = 24.93100897, test loss = 55.91244032
# epoch : 2853/5000, train loss = 24.93109256, test loss = 55.95146876
# epoch : 2854/5000, train loss = 24.93055040, test loss = 55.93796518
# epoch : 2855/5000, train loss = 24.93014926, test loss = 55.93887432
# epoch : 2856/5000, train loss = 24.93066235, test loss = 55.94689689
# epoch : 2857/5000, train loss = 24.93605642, test loss = 55.85154521
# epoch : 2858/5000, train loss = 24.93002490, test loss = 55.92157379
# epoch : 2859/5000, train loss = 24.93135398, test loss = 55.88581040
# epoch : 2860/5000, train loss = 24.93179999, test loss = 55.87417269
# epoch : 2861/5000, train loss = 24.92962349, test loss = 55.89251485
# epoch : 2862/5000, train loss = 24.93084539, test loss = 55.89067451
# epoch : 2863/5000, train loss = 24.92970939, test loss = 55.90940983
# epoch : 2864/5000, train loss = 24.92948695, test loss = 55.94902878
# epoch : 2865/5000, train loss = 24.92915537, test loss = 55.94099399
# epoch : 2866/5000, train loss = 24.92869776, test loss = 55.91966228
# epoch : 2867/5000, train loss = 24.92894673, test loss = 55.90145589
# epoch : 2868/5000, train loss = 24.93028060, test loss = 55.88215042
# epoch : 2869/5000, train loss = 24.93084021, test loss = 55.86835339
# epoch : 2870/5000, train loss = 24.93001990, test loss = 55.89506142
# epoch : 2871/5000, train loss = 24.92839942, test loss = 55.94091890
# epoch : 2872/5000, train loss = 24.92812849, test loss = 55.93959023
# epoch : 2873/5000, train loss = 24.92842910, test loss = 55.95960965
# epoch : 2874/5000, train loss = 24.92815547, test loss = 55.96278317
# epoch : 2875/5000, train loss = 24.92728492, test loss = 55.91222421
# epoch : 2876/5000, train loss = 24.92687789, test loss = 55.92285233
# epoch : 2877/5000, train loss = 24.92829397, test loss = 55.95626190
# epoch : 2878/5000, train loss = 24.93288514, test loss = 55.99491930
# epoch : 2879/5000, train loss = 24.93154966, test loss = 55.98243257
# epoch : 2880/5000, train loss = 24.92637649, test loss = 55.94301604
# epoch : 2881/5000, train loss = 24.92782332, test loss = 55.96117647
# epoch : 2882/5000, train loss = 24.92635143, test loss = 55.94322578
# epoch : 2883/5000, train loss = 24.92903973, test loss = 55.97246510
# epoch : 2884/5000, train loss = 24.92774843, test loss = 55.88477736
# epoch : 2885/5000, train loss = 24.92641672, test loss = 55.91716637
# epoch : 2886/5000, train loss = 24.92860449, test loss = 55.99190850
# epoch : 2887/5000, train loss = 24.92916285, test loss = 55.99255580
# epoch : 2888/5000, train loss = 24.93056143, test loss = 55.88856073
# epoch : 2889/5000, train loss = 24.92727348, test loss = 55.97249685
# epoch : 2890/5000, train loss = 24.92793223, test loss = 55.98078079
# epoch : 2891/5000, train loss = 24.92577035, test loss = 55.95060404
# epoch : 2892/5000, train loss = 24.92586728, test loss = 55.89924288
# epoch : 2893/5000, train loss = 24.92506223, test loss = 55.94376869
# epoch : 2894/5000, train loss = 24.92502902, test loss = 55.94064058
# epoch : 2895/5000, train loss = 24.92513202, test loss = 55.91679471
# epoch : 2896/5000, train loss = 24.92460541, test loss = 55.93219252
# epoch : 2897/5000, train loss = 24.92507850, test loss = 55.89476088
# epoch : 2898/5000, train loss = 24.92805993, test loss = 55.86521236
# epoch : 2899/5000, train loss = 24.92502235, test loss = 55.88570414
# epoch : 2900/5000, train loss = 24.92596598, test loss = 55.88803895
# epoch : 2901/5000, train loss = 24.92623992, test loss = 55.96826094
# epoch : 2902/5000, train loss = 24.92393894, test loss = 55.93805400
# epoch : 2903/5000, train loss = 24.92514694, test loss = 55.89791981
# epoch : 2904/5000, train loss = 24.92434247, test loss = 55.93588802
# epoch : 2905/5000, train loss = 24.92420418, test loss = 55.91264081
# epoch : 2906/5000, train loss = 24.92452086, test loss = 55.92757296
# epoch : 2907/5000, train loss = 24.92487635, test loss = 55.96927529
# epoch : 2908/5000, train loss = 24.92346488, test loss = 55.93476075
# epoch : 2909/5000, train loss = 24.92325624, test loss = 55.94369369
# epoch : 2910/5000, train loss = 24.92528102, test loss = 55.89575187
# epoch : 2911/5000, train loss = 24.92383701, test loss = 55.90906080
# epoch : 2912/5000, train loss = 24.92369052, test loss = 55.89542081
# epoch : 2913/5000, train loss = 24.92667404, test loss = 55.87330731
# epoch : 2914/5000, train loss = 24.92939712, test loss = 55.98095938
# epoch : 2915/5000, train loss = 24.92389597, test loss = 55.88510614
# epoch : 2916/5000, train loss = 24.93190510, test loss = 55.98988895
# epoch : 2917/5000, train loss = 24.92332138, test loss = 55.91112197
# epoch : 2918/5000, train loss = 24.92255393, test loss = 55.89207688
# epoch : 2919/5000, train loss = 24.92641533, test loss = 55.85764973
# epoch : 2920/5000, train loss = 24.92250978, test loss = 55.91868642
# epoch : 2921/5000, train loss = 24.92625467, test loss = 55.85654213
# epoch : 2922/5000, train loss = 24.92261900, test loss = 55.90395988
# epoch : 2923/5000, train loss = 24.92406312, test loss = 55.94656001
# epoch : 2924/5000, train loss = 24.92268996, test loss = 55.95253212
# epoch : 2925/5000, train loss = 24.92299941, test loss = 55.95241537
# epoch : 2926/5000, train loss = 24.92325074, test loss = 55.96343681
# epoch : 2927/5000, train loss = 24.92265518, test loss = 55.95939208
# epoch : 2928/5000, train loss = 24.92234898, test loss = 55.89727796
# epoch : 2929/5000, train loss = 24.92238979, test loss = 55.96702750
# epoch : 2930/5000, train loss = 24.92083095, test loss = 55.92702588
# epoch : 2931/5000, train loss = 24.92031976, test loss = 55.92707109
# epoch : 2932/5000, train loss = 24.92136250, test loss = 55.90413089
# epoch : 2933/5000, train loss = 24.92586539, test loss = 55.86503274
# epoch : 2934/5000, train loss = 24.92065367, test loss = 55.94100093
# epoch : 2935/5000, train loss = 24.92054941, test loss = 55.89927444
# epoch : 2936/5000, train loss = 24.92155175, test loss = 55.89480425
# epoch : 2937/5000, train loss = 24.92033841, test loss = 55.92888138
# epoch : 2938/5000, train loss = 24.92356630, test loss = 55.98551020
# epoch : 2939/5000, train loss = 24.91968751, test loss = 55.95410829
# epoch : 2940/5000, train loss = 24.92652534, test loss = 55.87902266
# epoch : 2941/5000, train loss = 24.93061274, test loss = 55.84545386
# epoch : 2942/5000, train loss = 24.92141304, test loss = 55.89937895
# epoch : 2943/5000, train loss = 24.92043716, test loss = 55.95803201
# epoch : 2944/5000, train loss = 24.92031399, test loss = 55.90513312
# epoch : 2945/5000, train loss = 24.91948561, test loss = 55.91675095
# epoch : 2946/5000, train loss = 24.92085413, test loss = 55.95717477
# epoch : 2947/5000, train loss = 24.91960033, test loss = 55.89840864
# epoch : 2948/5000, train loss = 24.91886774, test loss = 55.93499728
# epoch : 2949/5000, train loss = 24.91841800, test loss = 55.93927401
# epoch : 2950/5000, train loss = 24.92014219, test loss = 55.90114829
# epoch : 2951/5000, train loss = 24.92076685, test loss = 55.87773556
# epoch : 2952/5000, train loss = 24.91862848, test loss = 55.91402080
# epoch : 2953/5000, train loss = 24.91947726, test loss = 55.89907862
# epoch : 2954/5000, train loss = 24.91846862, test loss = 55.90158916
# epoch : 2955/5000, train loss = 24.91953382, test loss = 55.93703290
# epoch : 2956/5000, train loss = 24.92125573, test loss = 55.97068362
# epoch : 2957/5000, train loss = 24.92038918, test loss = 55.87567284
# epoch : 2958/5000, train loss = 24.91725390, test loss = 55.92823412
# epoch : 2959/5000, train loss = 24.91784295, test loss = 55.95097601
# epoch : 2960/5000, train loss = 24.91748622, test loss = 55.95256872
# epoch : 2961/5000, train loss = 24.91692073, test loss = 55.94091837
# epoch : 2962/5000, train loss = 24.91792276, test loss = 55.90492363
# epoch : 2963/5000, train loss = 24.91669831, test loss = 55.92632972
# epoch : 2964/5000, train loss = 24.91660201, test loss = 55.92548540
# epoch : 2965/5000, train loss = 24.91699308, test loss = 55.93793085
# epoch : 2966/5000, train loss = 24.91756795, test loss = 55.95758579
# epoch : 2967/5000, train loss = 24.91633923, test loss = 55.93563500
# epoch : 2968/5000, train loss = 24.92075143, test loss = 55.87267205
# epoch : 2969/5000, train loss = 24.91664447, test loss = 55.90358261
# epoch : 2970/5000, train loss = 24.91771027, test loss = 55.97067946
# epoch : 2971/5000, train loss = 24.91651387, test loss = 55.95777743
# epoch : 2972/5000, train loss = 24.91759598, test loss = 55.89612898
# epoch : 2973/5000, train loss = 24.91633420, test loss = 55.93566208
# epoch : 2974/5000, train loss = 24.91576461, test loss = 55.92590051
# epoch : 2975/5000, train loss = 24.91868935, test loss = 55.87674480
# epoch : 2976/5000, train loss = 24.91609403, test loss = 55.89903872
# epoch : 2977/5000, train loss = 24.91756734, test loss = 55.96997411
# epoch : 2978/5000, train loss = 24.91656064, test loss = 55.88488393
# epoch : 2979/5000, train loss = 24.91771395, test loss = 55.87447812
# epoch : 2980/5000, train loss = 24.91731532, test loss = 55.95471901
# epoch : 2981/5000, train loss = 24.91570140, test loss = 55.93642077
# epoch : 2982/5000, train loss = 24.91640006, test loss = 55.90322680
# epoch : 2983/5000, train loss = 24.91495381, test loss = 55.91899973
# epoch : 2984/5000, train loss = 24.91638893, test loss = 55.89529399
# epoch : 2985/5000, train loss = 24.91471354, test loss = 55.95259429
# epoch : 2986/5000, train loss = 24.91517099, test loss = 55.90035464
# epoch : 2987/5000, train loss = 24.91710371, test loss = 55.90838470
# epoch : 2988/5000, train loss = 24.91472057, test loss = 55.91050924
# epoch : 2989/5000, train loss = 24.91498561, test loss = 55.95015149
# epoch : 2990/5000, train loss = 24.92149086, test loss = 55.99713693
# epoch : 2991/5000, train loss = 24.91601480, test loss = 55.88487668
# epoch : 2992/5000, train loss = 24.91409652, test loss = 55.90137292
# epoch : 2993/5000, train loss = 24.91330281, test loss = 55.93041452
# epoch : 2994/5000, train loss = 24.91450359, test loss = 55.89641609
# epoch : 2995/5000, train loss = 24.91423399, test loss = 55.90034071
# epoch : 2996/5000, train loss = 24.91380515, test loss = 55.95376128
# epoch : 2997/5000, train loss = 24.91299151, test loss = 55.93909945
# epoch : 2998/5000, train loss = 24.92482991, test loss = 56.01996449
# epoch : 2999/5000, train loss = 24.91286262, test loss = 55.93095029
# epoch : 3000/5000, train loss = 24.91383919, test loss = 55.89820319
# epoch : 3001/5000, train loss = 24.91244021, test loss = 55.94699477
# epoch : 3002/5000, train loss = 24.91665954, test loss = 55.98162073
# epoch : 3003/5000, train loss = 24.91176978, test loss = 55.91631977
# epoch : 3004/5000, train loss = 24.91236885, test loss = 55.91272327
# epoch : 3005/5000, train loss = 24.91656034, test loss = 55.87483559
# epoch : 3006/5000, train loss = 24.91217306, test loss = 55.90003718
# epoch : 3007/5000, train loss = 24.91419642, test loss = 55.96868052
# epoch : 3008/5000, train loss = 24.91347417, test loss = 55.87424977
# epoch : 3009/5000, train loss = 24.91165675, test loss = 55.93795576
# epoch : 3010/5000, train loss = 24.91105900, test loss = 55.92238591
# epoch : 3011/5000, train loss = 24.91367097, test loss = 55.95676499
# epoch : 3012/5000, train loss = 24.91112267, test loss = 55.89676567
# epoch : 3013/5000, train loss = 24.91273227, test loss = 55.88760904
# epoch : 3014/5000, train loss = 24.91127898, test loss = 55.90262487
# epoch : 3015/5000, train loss = 24.91083265, test loss = 55.92161761
# epoch : 3016/5000, train loss = 24.91189455, test loss = 55.96568592
# epoch : 3017/5000, train loss = 24.91293911, test loss = 55.88045497
# epoch : 3018/5000, train loss = 24.91005953, test loss = 55.93040546
# epoch : 3019/5000, train loss = 24.91082900, test loss = 55.94576157
# epoch : 3020/5000, train loss = 24.91086457, test loss = 55.91797222
# epoch : 3021/5000, train loss = 24.91347901, test loss = 55.87557110
# epoch : 3022/5000, train loss = 24.91069455, test loss = 55.92451258
# epoch : 3023/5000, train loss = 24.91016160, test loss = 55.90953322
# epoch : 3024/5000, train loss = 24.91156664, test loss = 55.95317867
# epoch : 3025/5000, train loss = 24.91050091, test loss = 55.93961269
# epoch : 3026/5000, train loss = 24.91032149, test loss = 55.90551333
# epoch : 3027/5000, train loss = 24.91012934, test loss = 55.94343620
# epoch : 3028/5000, train loss = 24.90961605, test loss = 55.93592025
# epoch : 3029/5000, train loss = 24.91074401, test loss = 55.95834920
# epoch : 3030/5000, train loss = 24.91178415, test loss = 55.97535225
# epoch : 3031/5000, train loss = 24.90945287, test loss = 55.90836494
# epoch : 3032/5000, train loss = 24.90950784, test loss = 55.89747632
# epoch : 3033/5000, train loss = 24.90908608, test loss = 55.89937270
# epoch : 3034/5000, train loss = 24.90880818, test loss = 55.90970648
# epoch : 3035/5000, train loss = 24.91175868, test loss = 55.93452010
# epoch : 3036/5000, train loss = 24.90941022, test loss = 55.93573461
# epoch : 3037/5000, train loss = 24.90942814, test loss = 55.89930339
# epoch : 3038/5000, train loss = 24.90866471, test loss = 55.92114608
# epoch : 3039/5000, train loss = 24.90886731, test loss = 55.94834297
# epoch : 3040/5000, train loss = 24.91612175, test loss = 55.86481697
# epoch : 3041/5000, train loss = 24.91421408, test loss = 55.85472689
# epoch : 3042/5000, train loss = 24.91029624, test loss = 55.91020092
# epoch : 3043/5000, train loss = 24.90829156, test loss = 55.91791555
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [245], in <cell line: 1>()
# ----> 1 model, train_loss, test_loss = trainBAOReconNN(model, train_dataloader, test_dataloader, lr=2e-5, epochs=5000)
#
# Input In [218], in trainBAOReconNN(model, train_dataloader, test_dataloader, lr, epochs)
#      74 model_outputs = model(batch_features)
#      76 # compute training reconstruction loss
# ---> 77 train_loss = criterion(model_outputs, batch_labels)
#      79 # add the mini-batch training loss to epoch loss
#      80 train_loss_tot += train_loss.item()
#
# File /gpfs/gibbs/project/padmanabhan/ann22/conda_envs/bao/lib/python3.9/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /gpfs/gibbs/project/padmanabhan/ann22/conda_envs/bao/lib/python3.9/site-packages/torch/nn/modules/loss.py:530, in MSELoss.forward(self, input, target)
#     529 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 530     return F.mse_loss(input, target, reduction=self.reduction)
#
# File /gpfs/gibbs/project/padmanabhan/ann22/conda_envs/bao/lib/python3.9/site-packages/torch/nn/functional.py:3280, in mse_loss(input, target, size_average, reduce, reduction)
#    3277     reduction = _Reduction.legacy_get_string(size_average, reduce)
#    3279 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 3280 return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#
# KeyboardInterrupt:

# %% [markdown]
# #### Save/load trained neural network model

# %%
# run this cell to save the model
torch.save(model.state_dict(), 'scaleNNmodels/quickModel1.pth')

# %%
# run this cell to load the saved model
model = encoder(input_shape=input_shape, features=nFeatures).to(device)
model.load_state_dict(torch.load('scaleNNmodels/quickModel1.pth'))
model.eval()
# Out:
# encoder(
#   (encoder): Sequential(
#     (0): Linear(in_features=41, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=16, out_features=8, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=8, out_features=4, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=4, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# # Stuff to work on:
#
# (Done) 'De-normalize' the neural network outputs and look at plot with those
#
# (Working on) Try fitting polynomials to quijote z=0 or z=3 plots, getting linear points that way, and comparing.
#
# (Done) Look at omega_b/omega_m ratio for weird cosmologies 244, 763
#
# (Working on) Look at outliers in this plot
#
# (Done) Maybe check if residual from x=y in above plot correlates with omega_b or omega_m or something like that
#
# Try other networks/parameters
#
# Do stuff with fiducial cosmologies -- average a bunch, get linear point, can shift around in radial direction to change linear point, see what the model does, add noise, etc.

# %% [markdown]
# # 5. Analyze Trained Neural Network

# %% [markdown]
# #### De-normalize the neural network output linear points

# %%
mean_inputs, mean_lps, var_inputs, var_lps = meanVar(inputs_xi[:trainTestSplit], lps[:trainTestSplit])

# %%
model_lps = []
for i in inputs_xi:
    normalized_inputs = (np.copy(i) - mean_inputs)/var_inputs
    model_lp = model(torch.Tensor(normalized_inputs)).item()*var_lps+mean_lps
    model_lps.append(model_lp)

model_lps = np.array(model_lps)

# %%
lps_train = lps[:trainTestSplit]
model_lps_train = model_lps[:trainTestSplit]

lps_test = lps[trainTestSplit:]
model_lps_test = model_lps[trainTestSplit:]

# %% [markdown]
# ### Compare true linear point to linear point outputted by the neural network

# %%
fig = plt.figure(figsize=[4,4], dpi=200)
lineX = np.linspace(60, 140, 100)
plt.scatter(lps_test, model_lps_test, c='b', s=0.75, label='Validation Data')
plt.scatter(lps_train, model_lps_train, c='g', s=0.75, label='Training Data')

plt.plot(lineX, lineX, c='r', label='$x=y$')

plt.xlabel('Real LP')
plt.ylabel('Neural Network LP')
p = plt.legend()

# %% [markdown]
# ### Check if residuals correlate to cosmological parameters

# %%
trainResiduals = model_lps_train - lps_train
testResiduals = model_lps_test - lps_test

# %% [markdown]
# Pull Quijote parameters into a table (and remove the two CFs without a peak and/or dip)

# %%
simulation = 'latinHypercubeParameters.txt'
param_list = []
for line in open(simulation, 'r'): # get each line
    item = line.rstrip() # strip off newline and any other trailing whitespace
    param_list.append(item)

del param_list[0]

omegaMlist, omegaBlist, hList, nsList, s8list, cfList = [], [], [], [], [], []
i = 0
for item in param_list: # get radius and correlation from each line
    omegaM, omegaB, h, ns, s8 = item.split() # each line has both radius and correlation, so split
    omegaMlist.append(float(omegaM))
    omegaBlist.append(float(omegaB))
    hList.append(float(h))
    nsList.append(float(ns))
    s8list.append(float(s8))
    cfList.append(i)
    i += 1

    param_table = Table([cfList, omegaMlist, omegaBlist, hList, nsList, s8list],
                        names=('CF', 'omegaM', 'omegaB', 'h', 'ns', 's8')) # astropy table

# Keep the two "bad" CFs separate, then delete them
param244 = Table(param_table[244])
param763 = Table(param_table[763])

param_table.remove_rows([244, 763])

# %% [markdown]
# First look at the parameters for the two "bad" CFs

# %%
param244
# Out:
# <Table length=1>
#   CF   omegaM  omegaB    h       ns      s8
# int64 float64 float64 float64 float64 float64
# ----- ------- ------- ------- ------- -------
#   244  0.3207 0.03273  0.5145  0.8469  0.8307

# %%
param763
# Out:
# <Table length=1>
#   CF         omegaM        omegaB         h             ns           s8
# int64       float64       float64      float64       float64      float64
# ----- ------------------- ------- ------------------ ------- ------------------
#   763 0.26570000000000005 0.03033 0.5277000000000001  0.8373 0.9307000000000001

# %% [markdown]
# These seem to have relatively low $\Omega_b$ values, and maybe also low $h$ and $n_s$ values in the latin hypercube parameter space:
# <img src="quijoteParams.png" alt="Drawing" style="width: 200px;"/>
#
# Now look at the residuals

# %%
testOmegaM = param_table['omegaM'][trainTestSplit:]
testOmegaB = param_table['omegaB'][trainTestSplit:]

# %%
fig, ax = plt.subplots(3, figsize=[9,12], dpi=200)

ax[0].hlines(y=0, xmin=0, xmax=1, lw=0.5, color='r')
ax[1].hlines(y=0, xmin=0, xmax=1, lw=0.5, color='r')
ax[2].hlines(y=0, xmin=0, xmax=1, lw=0.5, color='r')
ax[0].scatter(testOmegaB/testOmegaM, testResiduals, s=1)
ax[1].scatter(testOmegaB, testResiduals, s=1)
ax[2].scatter(testOmegaM, testResiduals, s=1)

ax[0].set_xlim(0, 0.7)
ax[1].set_xlim(0.025, 0.075)
ax[2].set_xlim(0.09, 0.51)

ax[0].set_xlabel('$\Omega_b/\Omega_m$')
ax[1].set_xlabel('$\Omega_b$')
ax[2].set_xlabel('$\Omega_m$')

p = ax[1].set_ylabel('Neural Network LP - True LP')

# %% [markdown]
# #### Look at outliers individually

# %%
def plot3(number, z3scale=1):
    linCFfile = ascii.read(f'linearCF/linearCF{number}.dat')  
    linCF = Table(linCFfile)
    
    nonLin = txt_to_table(number, 0) # z = 0
    nonLin3 = txt_to_table(number, 3) # z = 3
    
    dip, peak, lp, ip = scales(linCF)
    
    # Plotting
    fig = plt.figure(figsize=[5, 2.5], dpi=500)

    spl = UnivariateSpline(linCF['r'], linCF['xi'], k=4, s=0) # degree 4 spline fit

    ## Add vertical/horizontal width in plot ##
    r_min, r_max = dip - 50, peak + 50
    if spl(peak) <= 0:
        xi_max = -1*spl(peak)
    else:
        xi_max = spl(peak)*1.2
    if np.min(linCF['xi']) <= 0:
        xi_min = np.min(linCF['xi'])*1.4
    else:
        xi_min = np.min(linCF['xi'])*0.8
        

    plt.plot(linCF['r'], linCF['xi'], c='r', label='Linear z=0 CF')

    plt.vlines([dip, peak], ymin=xi_min, ymax=xi_max, color='r', lw=0.5, ls='-.', label='Dip/peak')
    plt.vlines(lp, ymin=xi_min, ymax=xi_max, color='b', lw=0.5, ls='-.', label='LP')
    plt.vlines(ip, ymin=xi_min, ymax=xi_max, color='g', lw=0.5, ls='-.', label='IP')
    plt.scatter([dip, peak, lp, ip], [spl(dip), spl(peak), spl(lp), spl(ip)], c=['r', 'r', 'b', 'g'], s=2, zorder=1000)

    plt.plot(nonLin['r'], nonLin['xi'], label='Quijote z=0 CF', lw=2, c='b')
    plt.plot(nonLin3['r'], nonLin3['xi']*z3scale, label='Quijote z=3 CF', lw = 2, c='lime')


    # figure parameters
    plt.xlim(r_min, r_max)
    plt.ylim(xi_min, xi_max)


    plt.xlabel('r  $[h^{-1}$ Mpc]', fontsize=6)
    plt.ylabel('$\\xi(r)$', fontsize=6)
    plt.tick_params(axis='both', which='major', labelsize=6)
    plt.title('Correlation Function', fontsize=8)
    p = plt.legend(fontsize=4)

# %%
scaleTable[1925:1935]
# Out:
# <Table length=10>
#   CF         dip               peak                lp                 ip
# int64      float64           float64            float64            float64
# ----- ----------------- ------------------ ------------------ ------------------
#  1927 89.93748050899094 105.24907988920215  97.59328019909654  98.40677122590247
#  1928 77.49948399003436  90.25029254414683   83.8748882670906  84.22747189435829
#  1929 68.80874196118215  70.56108809705128  69.68491502911672  69.65864333285178
#  1930 76.84445317124317  89.24972110124452  83.04708713624385   83.5113218088701
#  1931 100.6252064696601 115.29585438880785 107.96053042923398 108.47600347208784
#  1932 74.99496084004717  88.31573673254722   81.6553487862972  82.50029799680269
#  1933 74.14793787413858  86.07797100303961   80.1129544385891    80.304687994264
#  1934 87.41400913471922 103.87563487131187  95.64482200301555  96.32653065714297
#  1935 76.22069493942647  88.96818381747445  82.59443937845046  83.33242836896694
#  1936 75.73182800395344  92.56290850412206  84.14736825403776  85.62273372466974

# %%
param_table[1925:1935]
# Out:
# <Table length=10>
#   CF         omegaM              omegaB        ...         ns            s8
# int64       float64             float64        ...      float64       float64
# ----- ------------------- -------------------- ... ------------------ -------
#  1927 0.18810000000000002  0.06873000000000001 ...             1.0081  0.6871
#  1928 0.43689999999999996  0.05371000000000001 ...             0.8871  0.7323
#  1929              0.4535              0.03573 ...             1.1101  0.6029
#  1930 0.46310000000000007  0.05969000000000001 ...             0.8453  0.8077
#  1931              0.1625 0.052390000000000006 ... 0.8289000000000001  0.9341
#  1932              0.4877 0.061090000000000005 ...             1.1693  0.8929
#  1933              0.4205              0.04981 ...             1.0025  0.9233
#  1934              0.2599              0.04569 ...             1.1961  0.6933
#  1935 0.46950000000000003              0.06317 ... 1.0716999999999999  0.9183
#  1936              0.4931              0.04365 ...             1.1667  0.7483

# %%
np.argmax(testResiduals[450:])
# Out:
# 478

# %%
model_lps_test[450+478]
# Out:
# 87.52773063582083

# %%
lps_test[450+478]
# Out:
# 69.68491502911672

# %%
plot3(1929, z3scale=10)
# Out:
# /gpfs/gibbs/project/padmanabhan/ann22/conda_envs/bao/lib/python3.9/site-packages/scipy/interpolate/_fitpack_impl.py:724: RuntimeWarning: The number of zeros exceeds mest
#   warnings.warn(RuntimeWarning("The number of zeros exceeds mest"))

# %% [markdown]
# Plot all 'bad' cases, also plot all power spectrum for them

# %% [markdown]
# # 6. Fitting Polynomials to Quijote CFs

# %%
def CFpolyFit(r, xi, rmin, rmax, deg):
    rMask = (r <= rmax) & (r >= rmin)
    poly = Polynomial.fit(r[rMask], xi[rMask], deg)
    
    return poly

# %%
def polyLP(r, xi, rmin, rmax, deg):
    poly = CFpolyFit(r, xi, rmin, rmax, deg)
    dPoly = poly.deriv()
    ddPoly = dPoly.deriv()
    criticalPoints = dPoly.roots()
    realCP = criticalPoints[np.isreal(criticalPoints)]
    dipPeak = np.real(realCP[(realCP >= rmin) & (realCP <= rmax)])
    if len(dipPeak) >= 2:
        if ddPoly(dipPeak[0]) >= 0:
            lp = (dipPeak[0] + dipPeak[1])/2.
            return lp
        elif len(dipPeak) > 2:
            lp = (dipPeak[1] + dipPeak[2])/2.
            return lp
        else:
            return 0
    else:
        return 0

# %%
def plot3poly(number):
    linCFfile = ascii.read(f'linearCF/linearCF{number}.dat')  
    linCF = Table(linCFfile)
    
    nonLin = txt_to_table(number, 0) # z = 0
    nonLin3 = txt_to_table(number, 3) # z = 3
    
    dip, peak, lp, ip = scales(linCF)
    
    # Plotting
    fig = plt.figure(figsize=[5, 2.5], dpi=500)

    spl = UnivariateSpline(linCF['r'], linCF['xi'], k=4, s=0) # degree 4 spline fit

    ## Add vertical/horizontal width in plot ##
    r_min, r_max = dip - 50, peak + 50
    xi_max = spl(peak)*1.2
    if np.min(linCF['xi']) <= 0:
        xi_min = np.min(linCF['xi'])*1.4
    else:
        xi_min = np.min(linCF['xi'])*0.8
        
    z3poly = CFpolyFit(nonLin3['r'], nonLin3['xi'], 60, 140, 9)
    z0poly = CFpolyFit(nonLin['r'], nonLin['xi'], 60, 140, 9)

    rr = np.linspace(r_min, r_max, 1000)
    plt.plot(rr, z3poly(rr), lw = 1, ls = '--', zorder=1000, label='Quijote z=3 Polyfit', c='darkred')
    plt.plot(rr, z0poly(rr), lw = 1, ls='--', zorder=1000, label='Quijote z=0 Polyfit', c='orange')

    plt.plot(linCF['r'], linCF['xi'], c='r', label='Linear z=0 CF')

    plt.vlines([dip, peak], ymin=xi_min, ymax=xi_max, color='r', lw=0.5, ls='-.', label='Dip/peak')
    plt.vlines(lp, ymin=xi_min, ymax=xi_max, color='b', lw=0.5, ls='-.', label='LP')
    plt.vlines(ip, ymin=xi_min, ymax=xi_max, color='g', lw=0.5, ls='-.', label='IP')
    plt.scatter([dip, peak, lp, ip], [spl(dip), spl(peak), spl(lp), spl(ip)], c=['r', 'r', 'b', 'g'], s=2, zorder=1000)

    plt.plot(nonLin['r'], nonLin['xi'], label='Quijote z=0 CF', lw=2, c='b')
    plt.plot(nonLin3['r'], nonLin3['xi'], label='Quijote z=3 CF', lw = 2, c='lime')






    # figure parameters
    plt.xlim(r_min, r_max)
    plt.ylim(xi_min, xi_max)


    plt.xlabel('r  $[h^{-1}$ Mpc]', fontsize=6)
    plt.ylabel('$\\xi(r)$', fontsize=6)
    plt.tick_params(axis='both', which='major', labelsize=6)
    plt.title('Correlation Function', fontsize=8)
    p = plt.legend(fontsize=4)

# %%
z0lpList, z3lpList, cfList = [], [], []

for x in scaleTable['CF']: # all simulations with scales
    cfList.append(x)
    nonLin0 = txt_to_table(x, 0) # z = 0
    nonLin3 = txt_to_table(x, 3) # z = 3
    
    z0lp = polyLP(nonLin0['r'], nonLin0['xi'], 60, 140, 9)
    z3lp = polyLP(nonLin3['r'], nonLin3['xi'], 60, 140, 9)
    
    
    z0lpList.append(z0lp)
    z3lpList.append(z3lp)

    
polyLPtable = Table([cfList, z0lpList, z3lpList],
                    names=('CF', 'z0PolyLP', 'z3PolyLP')) # astropy table

# %%
np.argmax(polyLPtable['z0PolyLP'])
# Out:
# 1862

# %%
polyLPtable[1862]
# Out:
# <Row index=1862>
#   CF       z0PolyLP           z3PolyLP
# int64      float64            float64
# ----- ------------------ -----------------
#  1864 137.64732784479492 93.48469749306359

# %%
plot3poly(1864)

# %%
xxxx = np.linspace(70, 140, 1000)
plt.plot(xxxx, xxxx, c='r')
plt.scatter(lps, polyLPtable['z0PolyLP'], s=0.75, c='r', label='z=0 Polyfit')
#plt.scatter(lps, polyLPtable['z3PolyLP'], s=0.75, c='orange', label='z=3 Polyfit')
plt.scatter(lps_test, model_lps_test, c='b', s=0.75, label='Validation Data')
#plt.scatter(lps_train, model_lps_train, c='g', s=0.75, label='Training Data')

plt.ylim(-10, 140)
p = plt.legend()
